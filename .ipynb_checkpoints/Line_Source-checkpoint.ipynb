# %%
import os
import shutil
from pathlib import Path

import pyvista as pv
import ogstools as ot
import ogstools.variables as ov

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from meshing import create_scylindre_mesh
from functions import pd_lsrf_nb, pd_lsrf_fb, find_roots_am, pwd_fsrf_fb, step_rate_r
from functions import scale_and_smooth, pickings

# %% [markdown]
# # Path

# %%
OGS_PATH = None

if OGS_PATH is not None:
    os.environ["OGS_BIN_PATH"] = OGS_PATH
OUT_DIR = Path(os.environ.get("OGS_TESTRUNNER_OUT_DIR", "_out"))
MESH_DIR = OUT_DIR / "mesh"
shutil.rmtree(OUT_DIR, ignore_errors=True)
MESH_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# # Line/finite-source and OGS model performance no-flow boundary pd,td SSS/no flow pwd,td SSS

# %% [markdown]
# ## Line-source analytical

# %%
k=5.35e-14
q=0.00016 #positive for production
# r=np.linspace(0.038,25,10) #array or r 

ddict={"p_i":0, #Pa
       "mu":1e-3 ,
       "B":1,
       "por":0.02,
       "c_t":4e-8,
       "r_w":0.038,
       "h": 10,
      }


def time_stepping_congruent(t_initial, t_final, n=50, bias_ratio=0.5): #produces OGS timestepping  congruently simultaneously
    t_split = t_final * 0.2
    n_start = max(2, int(n * bias_ratio))
    n_end = n - n_start + 1
    
    r1 = int(n_start - 1)
    r2 = int(n_end - 1)
    dt1 = (t_split - t_initial) / r1
    dt2 = (t_final - t_split) / r2
    
    t_segment1 = t_initial + np.arange(n_start) * dt1
    t_segment2 = t_split + np.arange(1, n_end) * dt2
    t_a = np.concatenate([t_segment1, t_segment2])
    
    t_a[-1] = t_final 
    return t_a, (r1, dt1), (r2, dt2)

# %% [markdown]
# ### Bounded no flow pd,td SSS

# %%
#General timestepping for analytical and OGS

t_initial=0
t_final=1000
t_initial_offset = 1e-10 
t, ts1, ts2 = time_stepping_congruent(t_initial, t_final, 200)

# %%
#Line source drawdown varying r with fixed k and re, bounded no flow 
k=k #same reference
rgeo=np.geomspace(ddict['r_w'], 15, 6).round(3) #initial random r or r_w

rinv=np.sqrt(k*max(t)/(ddict['por']*ddict['mu']*ddict['c_t']))
print("Investigation radius (m): ",f"{rinv:.2f}",'\n','"unperturbed" threshold (m): ', f"{4*rinv:.2f}")

r_col=rgeo
re=15
pi, mu, B,h= ddict['p_i'], ddict['mu'], ddict['B'],ddict['h']

C_vec = (mu * B) / (2 * np.pi * k * h)
term1_matrix = pd_lsrf_fb(t, ddict, k, r_col, re)

pwr0 = pi - (C_vec * q * term1_matrix)
print(f"Reservoir boundary: {re} m")

line_labels0 = [f"r = {val:>5.3f} m" for val in rgeo]

fig0, ax=plt.subplots()
ax.plot(t, pwr0/1e6,label=line_labels0) 

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / MPa")
plt.title(f"Line-source analytical nfb, re= {re} m, k={k} m^2")

plt.legend(loc='lower left')
plt.tight_layout()
plt.show()
# Out:
# Investigation radius (m):  8.18
#  "unperturbed" threshold (m):  32.71
# Reservoir boundary: 15 m

# %%
#Line source drawdown varying re with fixed k and r bounded no flow 
k=k #same ref
rgeo=ddict['r_w'] #initial random r or r_w

r_col=rgeo
re= np.geomspace(2, 15, 6).round(3) #initial random r or r_w

pi, mu, B,h,rw= ddict['p_i'], ddict['mu'], ddict['B'],ddict['h'],ddict['r_w']

C_vec = (mu * B) / (2 * np.pi * k * h)
term1_matrix = pd_lsrf_fb(t, ddict, k, r_col, re)

pwr1 = pi - (C_vec * q * term1_matrix)
print(f'Pressure at {rgeo} m reference')

line_labels1 = [f"re = {val:>5.1f} m" for val in re]

fig1, ax=plt.subplots()
ax.plot(t, pwr1/1e6,label=line_labels1) 

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / MPa")
plt.title(f"Line-source analytical nfb, rw= {rw} m, k={k} m^2")

plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Pressure at 0.038 m reference

# %% [markdown]
# ## Finite-source analytical

# %% [markdown]
# ### Bounded no flow pwd, td SSS
# Pressure at wellbore face pw

# %%
#Finite-source drawdown varying re with fixed k bounded no flow 
k=k #same reference

r_col=ddict['r_w']
re= np.geomspace(2,15,5).round(3)
pi, mu, B,h,rw= ddict['p_i'], ddict['mu'], ddict['B'], ddict['h'], ddict['r_w']

C_vec = (mu * B) / (2 * np.pi * k * h)
am= find_roots_am(rw, re,n_roots=1000)
term1_matrix = pwd_fsrf_fb(t, ddict, k, r_col, re,am)

pwr2 = pi - (C_vec * q * term1_matrix)
print(f"Reservoir boundary: {re} m")

line_labels2 = [f"re = {val:>5.2f} m" for val in re]

fig2, ax=plt.subplots()
ax.plot(t, pwr2/1e6,label=line_labels2) 

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / MPa")
plt.title(f"Finite-source analytical nfb, rw={rw} m, k ={k} m")

plt.legend()
plt.tight_layout()
plt.show()
#fig2.savefig(f"fsrfa_fb_2D_Ca.pdf",format='pdf')
# Out:
# Reservoir boundary: [ 2.     3.31   5.477  9.064 15.   ] m

# %%
#drawdown varying k, with fixed re=Rb
k=np.geomspace(5e-14,5e-15,5)

r_col=ddict['r_w']
re= 15
pi, mu, B,h,rw= ddict['p_i'], ddict['mu'], ddict['B'], ddict['h'], ddict['r_w']

C_vec = (mu * B) / (2 * np.pi * k * h)
am= find_roots_am(rw, re,n_roots=1000)
term1_matrix = pwd_fsrf_fb(t, ddict, k, r_col, re,am)

pwr3 = pi - (C_vec * q * term1_matrix)
print(f"Reservoir boundary: {re} m")


line_labels3 = [f"k = {val:>5.2e} m^2" for val in k]

fig3, ax=plt.subplots()
ax.plot(t, pwr3/1e6,label=line_labels3) 

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / MPa")
plt.title(f"Finite source analytical nfb, rw={rw} m, re ={re} m")

ax.legend(loc='lower left')
plt.tight_layout()
plt.show()
# Out:
# Reservoir boundary: 15 m

# %% [markdown]
# ## Numerical Model OGS

# %% [markdown]
# ### Meshing 2D Line/finite-Source

# %%
MSH_FILE = MESH_DIR / "symmetric_cylinder_2D.msh"

r_well=0.038
thickness=ddict['h']  
mesh_size=2

create_scylindre_mesh( 
        MSH_FILE,
        radius= 15,
        thickness= thickness,
        mesh_size= mesh_size,        #ideal 1/2 of thickness for symmetrical radial application
        r_well= r_well,      # Starting radius (0 for line, >0 for finite well radius in Neumann BC)
        refine_size= 0.05,     # standard 0.1 
        center_y= -20
        )

meshes = ot.meshes_from_gmsh(MSH_FILE, log=False)
for name, mesh in meshes.items():
    vtu_path = MESH_DIR / f"rectangle_{name}.vtu"
    pv.save_meshio(vtu_path, mesh)
    print(f"Saved {vtu_path}")
# Out:
# Saved _out\mesh\rectangle_domain.vtu
# Saved _out\mesh\rectangle_physical_group_top.vtu
# Saved _out\mesh\rectangle_physical_group_boundary_R.vtu
# Saved _out\mesh\rectangle_physical_group_bottom.vtu
# Saved _out\mesh\rectangle_physical_group_well.vtu
# Saved _out\mesh\rectangle_physical_group_domain.vtu

# %%
fig4 = meshes["domain"].plot_contourf(
    "MaterialIDs",
    figsize=(8, 6),
    dpi=100,
    cmap="tab20",
    alpha=0.3,
    linewidth=0,
)
ax = fig4.axes[0]
for i, (name, mesh) in enumerate(sorted(meshes.items())):
    if mesh.area:  
        continue
    ls, marker = ("-", "") if "boundary" in name else ("-", "o")
    ot.plot.line(
        mesh,
        ax=ax,
        color=f"C{i}",
        lw=2,
        ls=ls,
        marker=marker,
        markersize=8,
        label=name,
    )
#ax.set_aspect("equal")
ax.set_xlabel('r / m')
ax.legend(ncol=2, fontsize=10, frameon=False)
plt.show()
# Out:
# C:\Users\acer\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### PRJ file pre-procesing

# %%
k_ref= 5.35e-14
ct_ref= ddict["c_t"]*ddict['por'] #OGS storage is scale down by por analytical

# %%
PROJECT_BASENAME = "Line_source" 
prj_in = Path(f"{PROJECT_BASENAME}.prj")
prj_out = OUT_DIR / f"{PROJECT_BASENAME}_updated.prj"

prj = ot.Project(input_file=prj_in, output_file=prj_out)

# %%
root = prj.tree.getroot()
mesh_nodes = root.findall("./meshes/mesh")

if mesh_nodes:
    for mesh_node in mesh_nodes:
        is_axial = mesh_node.get("axially_symmetric")
        
        if is_axial != "true":
            mesh_node.set("axially_symmetric", "true")
            print(f"Added axial symmetry to: {mesh_node.text}")
        else:
            print(f"Axial symmetry already active for: {mesh_node.text}")
else:
    print("Error: No <mesh> tags found in the <meshes> section.")
# Out:
# Added axial symmetry to: rectangle_domain.vtu
# Added axial symmetry to: rectangle_physical_group_bottom.vtu
# Added axial symmetry to: rectangle_physical_group_top.vtu
# Added axial symmetry to: rectangle_physical_group_well.vtu
# Added axial symmetry to: rectangle_physical_group_boundary_R.vtu

# %%
v_in=-1*q/(2*np.pi*r_well*ddict['h']) #changing to proudction OGS (-q), changing changing to flux based upon r_well building mesh

boundary_condition='no_flow_boundary' #options: infinite, no_flow_boundary, pressure_boundary
target_mesh = "rectangle_physical_group_boundary_R"

def mesh_condition(boundary,target,ddict=ddict):
    xpath=f"./process_variables/process_variable/boundary_conditions/boundary_condition[mesh='{target}']/type"
    bc={"infinite":'Dirichlet',"no_flow_boundary":'Neumann', "pressure_boundary":'Dirichlet'}

    if boundary in bc:
        prj.replace_text(bc[boundary], xpath=xpath)
        print(f"Updated {target} to {bc[boundary]}")
        
        if boundary=='no_flow_boundary':
            prj.replace_parameter_value(name="pi_bd", value=0)
            value_r=0
        else:
            prj.replace_parameter_value(name="pi_bd", value=ddict["p_i"]) 
            value_r=ddict["p_i"]
        print(f"Updated {target} value to {value_r}") 
    else:
        print(f"Error: '{boundary}' is not a valid boundary option.") 

try:
    mesh_condition(boundary_condition,target_mesh)
    
    prj.replace_parameter_value(name="p0", value=ddict["p_i"])
    prj.replace_parameter_value(name="q_in", value=v_in)

    mid=0
    prj.replace_phase_property_value(mediumid=mid, phase="AqueousLiquid", name="viscosity", value=ddict["mu"])
    
    prj.replace_medium_property_value(mediumid=mid, name="porosity", value=ddict["por"])
    prj.replace_medium_property_value(mediumid=mid, name="permeability", value=k_ref)
    prj.replace_medium_property_value(mediumid=mid, name="storage", value= ct_ref)

    print("media/properties, Parameters updated")
except Exception as e:
    print(f"Error occurred: {e}")
# Out:
# Updated rectangle_physical_group_boundary_R to Neumann
# Updated rectangle_physical_group_boundary_R value to 0
# media/properties, Parameters updated

# %%
#timestepping calculations 
try:
    prj.replace_text(t[0], 
                     xpath="./time_loop/processes/process/time_stepping/t_initial")
    prj.replace_text(t[-1],
                     xpath="./time_loop/processes/process/time_stepping/t_end")
    
    prj.replace_text(ts1[0],
                     xpath="./time_loop/processes/process/time_stepping/timesteps/pair/repeat")
    prj.replace_text(ts1[1], 
        xpath="./time_loop/processes/process/time_stepping/timesteps/pair/delta_t")

    prj.add_block( #new block to cover resolution
    blocktag="pair",
    parent_xpath="./time_loop/processes/process/time_stepping/timesteps",
    taglist=["repeat", "delta_t"],
    textlist=[ts2[0], ts2[1]]  
     )
    print('time stepping calculation repeat/delta_t', ts1, '\t', ts2)

    #out 
    prj.replace_text(ts1[0],
                     xpath="./time_loop/output/timesteps/pair/repeat")
    prj.replace_text('1', 
                    xpath="./time_loop/output/timesteps/pair/each_steps")

    prj.add_block( #new block to cover resolution
    blocktag="pair",
    parent_xpath="./time_loop/output/timesteps",
    taglist=["repeat", "each_steps"],
    textlist=[ts2[0], '1']  
     )
    
    print("ouput_res: timestep/each_steps", ts1, '\t', ts2)
except Exception as e:
    print(f"Error occurred: {e}")
    
prj.write_input()
print('\n', f"prj update in {prj_out} as {PROJECT_BASENAME}_updated.prj")
# Out:
# time stepping calculation repeat/delta_t (99, 2.0202020202020203) 	 (100, 8.0)
# ouput_res: timestep/each_steps (99, 2.0202020202020203) 	 (100, 8.0)
#
#  prj update in _out\Line_source_updated.prj as Line_source_updated.prj

# %% [markdown]
# ### Running OGS

# %%
# !ogs ./_out/Line_source_updated.prj -m ./_out/mesh -o ./_out/
# Out:
# info: This is OpenGeoSys-6 version 6.5.5.
# info: OGS started on 2026-03-27 12:06:55+0100.
# warning: OMP_NUM_THREADS is not set, falling back to: 16
# info: Eigen use 16 threads
# info: Reading project file _out\Line_source_updated.prj.
# info: readRasters ...
# info: readRasters done
# info: ConstantParameter: p0
# info: ConstantParameter: p_tb
# info: ConstantParameter: pi_bd
# info: ConstantParameter: constant_porosity_parameter
# info: ConstantParameter: q_in
# info: No source terms for process variable 'pressure' found.
# info: Initialize processes.
# info: Time step #0 started. Time: 0. Step size: 0.
# info: [time] Output of timestep 0 took 0.0249565 s.
# info: Time step #0 took 0.0276319 s.
# info: OpenGeoSys is now initialized.
# info: OGS started on 2026-03-27 12:06:56+0100.
# info: Solve processes.
# info: Time step #1 started. Time: 2.0202020202020203. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0078212 s.
# info: [time] Applying Dirichlet BCs took 0.0001835 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 233/10000
# info: 	 residual: 9.993100e-21
#
# info: [time] Linear solver took 0.0062914 s.
# info: Convergence criterion: |dx|=2.4382e+06, |x|=2.4382e+06, |dx|/|x|=1.0000e+00
# info: [time] Iteration #1 took 0.0143828 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.005835 s.
# info: [time] Applying Dirichlet BCs took 0.000136 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 68/10000
# info: 	 residual: 9.872578e-21
#
# info: [time] Linear solver took 0.0016408 s.
# info: Convergence criterion: |dx|=1.7937e-09, |x|=2.4382e+06, |dx|/|x|=7.3567e-16
# info: [time] Iteration #2 took 0.0076415 s.
# info: [time] Solving process #0 took 0.0221573 s in time step #1
# info: [time] Time step #1 took 0.0237938 s.
# info: [time] Output of timestep 1 took 0.0145559 s.
# info: Time step #2 started. Time: 4.0404040404040407. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0058491 s.
# info: [time] Applying Dirichlet BCs took 0.0001852 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 229/10000
# info: 	 residual: 8.652628e-21
#
# info: [time] Linear solver took 0.0053323 s.
# info: Convergence criterion: |dx|=7.7268e+05, |x|=3.1673e+06, |dx|/|x|=2.4395e-01
# info: [time] Iteration #1 took 0.01142 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0056231 s.
# info: [time] Applying Dirichlet BCs took 0.0001225 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 71/10000
# info: 	 residual: 9.299292e-21
#
# info: [time] Linear solver took 0.001707 s.
# info: Convergence criterion: |dx|=2.9318e-09, |x|=3.1673e+06, |dx|/|x|=9.2562e-16
# info: [time] Iteration #2 took 0.0074804 s.
# info: [time] Solving process #0 took 0.0190039 s in time step #2
# info: [time] Time step #2 took 0.020411 s.
# info: [time] Output of timestep 2 took 0.0147412 s.
# info: Time step #3 started. Time: 6.0606060606060606. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0058978 s.
# info: [time] Applying Dirichlet BCs took 0.000191 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 228/10000
# info: 	 residual: 9.236675e-21
#
# info: [time] Linear solver took 0.0053197 s.
# info: Convergence criterion: |dx|=4.4151e+05, |x|=3.5819e+06, |dx|/|x|=1.2326e-01
# info: [time] Iteration #1 took 0.0114588 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0057992 s.
# info: [time] Applying Dirichlet BCs took 0.0001368 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 69/10000
# info: 	 residual: 9.997852e-21
#
# info: [time] Linear solver took 0.0016665 s.
# info: Convergence criterion: |dx|=3.1459e-09, |x|=3.5819e+06, |dx|/|x|=8.7827e-16
# info: [time] Iteration #2 took 0.0076403 s.
# info: [time] Solving process #0 took 0.0192168 s in time step #3
# info: [time] Time step #3 took 0.0205512 s.
# info: [time] Output of timestep 3 took 0.0145143 s.
# info: Time step #4 started. Time: 8.0808080808080813. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0059742 s.
# info: [time] Applying Dirichlet BCs took 0.0001875 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 227/10000
# info: 	 residual: 7.804576e-21
#
# info: [time] Linear solver took 0.0052946 s.
# info: Convergence criterion: |dx|=3.0662e+05, |x|=3.8704e+06, |dx|/|x|=7.9222e-02
# info: [time] Iteration #1 took 0.0115133 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0057195 s.
# info: [time] Applying Dirichlet BCs took 0.0001234 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 68/10000
# info: 	 residual: 8.796538e-21
#
# info: [time] Linear solver took 0.0016988 s.
# info: Convergence criterion: |dx|=3.1458e-09, |x|=3.8704e+06, |dx|/|x|=8.1280e-16
# info: [time] Iteration #2 took 0.0075745 s.
# info: [time] Solving process #0 took 0.0192007 s in time step #4
# info: [time] Time step #4 took 0.0205554 s.
# info: [time] Output of timestep 4 took 0.0154203 s.
# info: Time step #5 started. Time: 10.101010101010102. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0057976 s.
# info: [time] Applying Dirichlet BCs took 0.0002043 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 226/10000
# info: 	 residual: 7.526524e-21
#
# info: [time] Linear solver took 0.0053782 s.
# info: Convergence criterion: |dx|=2.3454e+05, |x|=4.0915e+06, |dx|/|x|=5.7323e-02
# info: [time] Iteration #1 took 0.0114419 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0056891 s.
# info: [time] Applying Dirichlet BCs took 0.0001367 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 65/10000
# info: 	 residual: 9.314767e-21
#
# info: [time] Linear solver took 0.0015764 s.
# info: Convergence criterion: |dx|=3.5317e-09, |x|=4.0915e+06, |dx|/|x|=8.6318e-16
# info: [time] Iteration #2 took 0.0074356 s.
# info: [time] Solving process #0 took 0.0189937 s in time step #5
# info: [time] Time step #5 took 0.0203063 s.
# info: [time] Output of timestep 5 took 0.0167158 s.
# info: Time step #6 started. Time: 12.121212121212121. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0059788 s.
# info: [time] Applying Dirichlet BCs took 0.0002 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 224/10000
# info: 	 residual: 8.700676e-21
#
# info: [time] Linear solver took 0.0053893 s.
# info: Convergence criterion: |dx|=1.8988e+05, |x|=4.2709e+06, |dx|/|x|=4.4459e-02
# info: [time] Iteration #1 took 0.0116272 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0055023 s.
# info: [time] Applying Dirichlet BCs took 0.0001332 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 65/10000
# info: 	 residual: 9.797380e-21
#
# info: [time] Linear solver took 0.0029161 s.
# info: Convergence criterion: |dx|=4.0126e-09, |x|=4.2709e+06, |dx|/|x|=9.3952e-16
# info: [time] Iteration #2 took 0.008592 s.
# info: [time] Solving process #0 took 0.0203272 s in time step #6
# info: [time] Time step #6 took 0.0219471 s.
# info: [time] Output of timestep 6 took 0.0164726 s.
# info: Time step #7 started. Time: 14.141414141414142. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0064797 s.
# info: [time] Applying Dirichlet BCs took 0.0002036 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 223/10000
# info: 	 residual: 8.970183e-21
#
# info: [time] Linear solver took 0.0080855 s.
# info: Convergence criterion: |dx|=1.5953e+05, |x|=4.4219e+06, |dx|/|x|=3.6078e-02
# info: [time] Iteration #1 took 0.0148474 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0066069 s.
# info: [time] Applying Dirichlet BCs took 0.0001442 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 65/10000
# info: 	 residual: 9.754608e-21
#
# info: [time] Linear solver took 0.0015769 s.
# info: Convergence criterion: |dx|=3.9868e-09, |x|=4.4219e+06, |dx|/|x|=9.0160e-16
# info: [time] Iteration #2 took 0.0083781 s.
# info: [time] Solving process #0 took 0.0233687 s in time step #7
# info: [time] Time step #7 took 0.0248601 s.
# info: [time] Output of timestep 7 took 0.014971 s.
# info: Time step #8 started. Time: 16.161616161616163. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0058186 s.
# info: [time] Applying Dirichlet BCs took 0.0002161 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 222/10000
# info: 	 residual: 7.744706e-21
#
# info: [time] Linear solver took 0.0051721 s.
# info: Convergence criterion: |dx|=1.3758e+05, |x|=4.5523e+06, |dx|/|x|=3.0223e-02
# info: [time] Iteration #1 took 0.011256 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0059897 s.
# info: [time] Applying Dirichlet BCs took 0.0001247 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 62/10000
# info: 	 residual: 9.730572e-21
#
# info: [time] Linear solver took 0.0015556 s.
# info: Convergence criterion: |dx|=3.7401e-09, |x|=4.5523e+06, |dx|/|x|=8.2160e-16
# info: [time] Iteration #2 took 0.0076997 s.
# info: [time] Solving process #0 took 0.019062 s in time step #8
# info: [time] Time step #8 took 0.0205586 s.
# info: [time] Output of timestep 8 took 0.0166181 s.
# info: Time step #9 started. Time: 18.181818181818183. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0060342 s.
# info: [time] Applying Dirichlet BCs took 0.0002146 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 220/10000
# info: 	 residual: 9.315535e-21
#
# info: [time] Linear solver took 0.0051247 s.
# info: Convergence criterion: |dx|=1.2097e+05, |x|=4.6670e+06, |dx|/|x|=2.5920e-02
# info: [time] Iteration #1 took 0.0114307 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0061858 s.
# info: [time] Applying Dirichlet BCs took 0.000132 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 63/10000
# info: 	 residual: 9.491313e-21
#
# info: [time] Linear solver took 0.0015235 s.
# info: Convergence criterion: |dx|=3.8000e-09, |x|=4.6670e+06, |dx|/|x|=8.1422e-16
# info: [time] Iteration #2 took 0.0078801 s.
# info: [time] Solving process #0 took 0.0194423 s in time step #9
# info: [time] Time step #9 took 0.0207813 s.
# info: [time] Output of timestep 9 took 0.0145733 s.
# info: Time step #10 started. Time: 20.202020202020204. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0057725 s.
# info: [time] Applying Dirichlet BCs took 0.0002047 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 220/10000
# info: 	 residual: 7.437506e-21
#
# info: [time] Linear solver took 0.0053401 s.
# info: Convergence criterion: |dx|=1.0795e+05, |x|=4.7695e+06, |dx|/|x|=2.2634e-02
# info: [time] Iteration #1 took 0.0113696 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0056655 s.
# info: [time] Applying Dirichlet BCs took 0.000137 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 64/10000
# info: 	 residual: 8.783454e-21
#
# info: [time] Linear solver took 0.0015488 s.
# info: Convergence criterion: |dx|=4.4549e-09, |x|=4.7695e+06, |dx|/|x|=9.3404e-16
# info: [time] Iteration #2 took 0.0073832 s.
# info: [time] Solving process #0 took 0.0188609 s in time step #10
# info: [time] Time step #10 took 0.0201849 s.
# info: [time] Output of timestep 10 took 0.0144516 s.
# info: Time step #11 started. Time: 22.222222222222225. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0057881 s.
# info: [time] Applying Dirichlet BCs took 0.000199 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 218/10000
# info: 	 residual: 9.605716e-21
#
# info: [time] Linear solver took 0.0051842 s.
# info: Convergence criterion: |dx|=9.7478e+04, |x|=4.8622e+06, |dx|/|x|=2.0048e-02
# info: [time] Iteration #1 took 0.0112217 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0056086 s.
# info: [time] Applying Dirichlet BCs took 0.0001324 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 63/10000
# info: 	 residual: 8.629755e-21
#
# info: [time] Linear solver took 0.0015284 s.
# info: Convergence criterion: |dx|=4.4068e-09, |x|=4.8622e+06, |dx|/|x|=9.0634e-16
# info: [time] Iteration #2 took 0.0072988 s.
# info: [time] Solving process #0 took 0.0186269 s in time step #11
# info: [time] Time step #11 took 0.0199305 s.
# info: [time] Output of timestep 11 took 0.0147562 s.
# info: Time step #12 started. Time: 24.242424242424242. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.005904 s.
# info: [time] Applying Dirichlet BCs took 0.0002116 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 218/10000
# info: 	 residual: 8.783363e-21
#
# info: [time] Linear solver took 0.0050603 s.
# info: Convergence criterion: |dx|=8.8867e+04, |x|=4.9467e+06, |dx|/|x|=1.7965e-02
# info: [time] Iteration #1 took 0.0112323 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0062012 s.
# info: [time] Applying Dirichlet BCs took 0.0001271 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 63/10000
# info: 	 residual: 7.751887e-21
#
# info: [time] Linear solver took 0.0015232 s.
# info: Convergence criterion: |dx|=4.6965e-09, |x|=4.9467e+06, |dx|/|x|=9.4942e-16
# info: [time] Iteration #2 took 0.0078791 s.
# info: [time] Solving process #0 took 0.0192194 s in time step #12
# info: [time] Time step #12 took 0.0205417 s.
# info: [time] Output of timestep 12 took 0.0146134 s.
# info: Time step #13 started. Time: 26.262626262626263. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0058598 s.
# info: [time] Applying Dirichlet BCs took 0.0002062 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 217/10000
# info: 	 residual: 9.008984e-21
#
# info: [time] Linear solver took 0.0050636 s.
# info: Convergence criterion: |dx|=8.1660e+04, |x|=5.0244e+06, |dx|/|x|=1.6253e-02
# info: [time] Iteration #1 took 0.0111781 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0058758 s.
# info: [time] Applying Dirichlet BCs took 0.0001298 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 61/10000
# info: 	 residual: 9.097541e-21
#
# info: [time] Linear solver took 0.0014998 s.
# info: Convergence criterion: |dx|=4.0330e-09, |x|=5.0244e+06, |dx|/|x|=8.0267e-16
# info: [time] Iteration #2 took 0.0075427 s.
# info: [time] Solving process #0 took 0.0188376 s in time step #13
# info: [time] Time step #13 took 0.0202365 s.
# info: [time] Output of timestep 13 took 0.0146623 s.
# info: Time step #14 started. Time: 28.282828282828284. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0057606 s.
# info: [time] Applying Dirichlet BCs took 0.0002077 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 217/10000
# info: 	 residual: 7.898589e-21
#
# info: [time] Linear solver took 0.0050576 s.
# info: Convergence criterion: |dx|=7.5539e+04, |x|=5.0964e+06, |dx|/|x|=1.4822e-02
# info: [time] Iteration #1 took 0.011085 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0056804 s.
# info: [time] Applying Dirichlet BCs took 0.0001253 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 62/10000
# info: 	 residual: 9.207797e-21
#
# info: [time] Linear solver took 0.0015796 s.
# info: Convergence criterion: |dx|=4.8737e-09, |x|=5.0964e+06, |dx|/|x|=9.5630e-16
# info: [time] Iteration #2 took 0.0074132 s.
# info: [time] Solving process #0 took 0.0186029 s in time step #14
# info: [time] Time step #14 took 0.0199367 s.
# info: [time] Output of timestep 14 took 0.0143579 s.
# info: Time step #15 started. Time: 30.303030303030305. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0058255 s.
# info: [time] Applying Dirichlet BCs took 0.0002073 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 216/10000
# info: 	 residual: 8.753124e-21
#
# info: [time] Linear solver took 0.0051405 s.
# info: Convergence criterion: |dx|=7.0275e+04, |x|=5.1634e+06, |dx|/|x|=1.3610e-02
# info: [time] Iteration #1 took 0.0112279 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0060465 s.
# info: [time] Applying Dirichlet BCs took 0.000136 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 60/10000
# info: 	 residual: 9.930090e-21
#
# info: [time] Linear solver took 0.0014609 s.
# info: Convergence criterion: |dx|=5.4894e-09, |x|=5.1634e+06, |dx|/|x|=1.0632e-15
# info: [time] Iteration #2 took 0.0076776 s.
# info: [time] Solving process #0 took 0.0190147 s in time step #15
# info: [time] Time step #15 took 0.0203337 s.
# info: [time] Output of timestep 15 took 0.0144809 s.
# info: Time step #16 started. Time: 32.323232323232325. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0057918 s.
# info: [time] Applying Dirichlet BCs took 0.0001837 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 215/10000
# info: 	 residual: 9.673229e-21
#
# info: [time] Linear solver took 0.005082 s.
# info: Convergence criterion: |dx|=6.5700e+04, |x|=5.2260e+06, |dx|/|x|=1.2572e-02
# info: [time] Iteration #1 took 0.0111112 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0058935 s.
# info: [time] Applying Dirichlet BCs took 0.0001327 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 61/10000
# info: 	 residual: 9.470387e-21
#
# info: [time] Linear solver took 0.0014788 s.
# info: Convergence criterion: |dx|=4.6271e-09, |x|=5.2260e+06, |dx|/|x|=8.8539e-16
# info: [time] Iteration #2 took 0.0075336 s.
# info: [time] Solving process #0 took 0.0187414 s in time step #16
# info: [time] Time step #16 took 0.0200469 s.
# info: [time] Output of timestep 16 took 0.0143726 s.
# info: Time step #17 started. Time: 34.343434343434346. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0061621 s.
# info: [time] Applying Dirichlet BCs took 0.0002047 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 214/10000
# info: 	 residual: 9.846493e-21
#
# info: [time] Linear solver took 0.0050515 s.
# info: Convergence criterion: |dx|=6.1686e+04, |x|=5.2849e+06, |dx|/|x|=1.1672e-02
# info: [time] Iteration #1 took 0.0114851 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0060379 s.
# info: [time] Applying Dirichlet BCs took 0.0001351 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 60/10000
# info: 	 residual: 9.801517e-21
#
# info: [time] Linear solver took 0.001458 s.
# info: Convergence criterion: |dx|=4.6436e-09, |x|=5.2849e+06, |dx|/|x|=8.7867e-16
# info: [time] Iteration #2 took 0.0076642 s.
# info: [time] Solving process #0 took 0.0192567 s in time step #17
# info: [time] Time step #17 took 0.0205957 s.
# info: [time] Output of timestep 17 took 0.0144156 s.
# info: Time step #18 started. Time: 36.363636363636367. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0060703 s.
# info: [time] Applying Dirichlet BCs took 0.0002009 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 213/10000
# info: 	 residual: 9.093038e-21
#
# info: [time] Linear solver took 0.0064616 s.
# info: Convergence criterion: |dx|=5.8135e+04, |x|=5.3404e+06, |dx|/|x|=1.0886e-02
# info: [time] Iteration #1 took 0.0127902 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0056734 s.
# info: [time] Applying Dirichlet BCs took 0.0001275 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 60/10000
# info: 	 residual: 8.260916e-21
#
# info: [time] Linear solver took 0.0014616 s.
# info: Convergence criterion: |dx|=4.5056e-09, |x|=5.3404e+06, |dx|/|x|=8.4369e-16
# info: [time] Iteration #2 took 0.0072985 s.
# info: [time] Solving process #0 took 0.0201914 s in time step #18
# info: [time] Time step #18 took 0.0215182 s.
# info: [time] Output of timestep 18 took 0.0146089 s.
# info: Time step #19 started. Time: 38.383838383838388. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0057715 s.
# info: [time] Applying Dirichlet BCs took 0.0002006 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 213/10000
# info: 	 residual: 8.187513e-21
#
# info: [time] Linear solver took 0.0049629 s.
# info: Convergence criterion: |dx|=5.4973e+04, |x|=5.3928e+06, |dx|/|x|=1.0194e-02
# info: [time] Iteration #1 took 0.0109904 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0064937 s.
# info: [time] Applying Dirichlet BCs took 0.0001376 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 59/10000
# info: 	 residual: 9.972027e-21
#
# info: [time] Linear solver took 0.0014631 s.
# info: Convergence criterion: |dx|=4.7594e-09, |x|=5.3928e+06, |dx|/|x|=8.8253e-16
# info: [time] Iteration #2 took 0.0081437 s.
# info: [time] Solving process #0 took 0.0192445 s in time step #19
# info: [time] Time step #19 took 0.02063 s.
# info: [time] Output of timestep 19 took 0.0143558 s.
# info: Time step #20 started. Time: 40.404040404040408. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0058287 s.
# info: [time] Applying Dirichlet BCs took 0.0002111 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 212/10000
# info: 	 residual: 9.456298e-21
#
# info: [time] Linear solver took 0.0049432 s.
# info: Convergence criterion: |dx|=5.2137e+04, |x|=5.4427e+06, |dx|/|x|=9.5794e-03
# info: [time] Iteration #1 took 0.0110333 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0053425 s.
# info: [time] Applying Dirichlet BCs took 0.0001301 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 59/10000
# info: 	 residual: 8.480777e-21
#
# info: [time] Linear solver took 0.001492 s.
# info: Convergence criterion: |dx|=4.0509e-09, |x|=5.4427e+06, |dx|/|x|=7.4430e-16
# info: [time] Iteration #2 took 0.0069929 s.
# info: [time] Solving process #0 took 0.0181223 s in time step #20
# info: [time] Time step #20 took 0.01947 s.
# info: [time] Output of timestep 20 took 0.0154937 s.
# info: Time step #21 started. Time: 42.424242424242429. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0058464 s.
# info: [time] Applying Dirichlet BCs took 0.0001852 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 211/10000
# info: 	 residual: 9.997109e-21
#
# info: [time] Linear solver took 0.0051765 s.
# info: Convergence criterion: |dx|=4.9581e+04, |x|=5.4900e+06, |dx|/|x|=9.0311e-03
# info: [time] Iteration #1 took 0.0112671 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0056179 s.
# info: [time] Applying Dirichlet BCs took 0.0001389 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 58/10000
# info: 	 residual: 9.451243e-21
#
# info: [time] Linear solver took 0.0014147 s.
# info: Convergence criterion: |dx|=4.1841e-09, |x|=5.4900e+06, |dx|/|x|=7.6213e-16
# info: [time] Iteration #2 took 0.0072089 s.
# info: [time] Solving process #0 took 0.0185728 s in time step #21
# info: [time] Time step #21 took 0.0199009 s.
# info: [time] Output of timestep 21 took 0.0148168 s.
# info: Time step #22 started. Time: 44.44444444444445. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.00616 s.
# info: [time] Applying Dirichlet BCs took 0.0002943 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 211/10000
# info: 	 residual: 8.836156e-21
#
# info: [time] Linear solver took 0.0049167 s.
# info: Convergence criterion: |dx|=4.7264e+04, |x|=5.5352e+06, |dx|/|x|=8.5388e-03
# info: [time] Iteration #1 took 0.0114258 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0056522 s.
# info: [time] Applying Dirichlet BCs took 0.000134 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 58/10000
# info: 	 residual: 9.693384e-21
#
# info: [time] Linear solver took 0.001427 s.
# info: Convergence criterion: |dx|=4.8256e-09, |x|=5.5352e+06, |dx|/|x|=8.7179e-16
# info: [time] Iteration #2 took 0.007246 s.
# info: [time] Solving process #0 took 0.0187839 s in time step #22
# info: [time] Time step #22 took 0.0201651 s.
# info: [time] Output of timestep 22 took 0.0181609 s.
# info: Time step #23 started. Time: 46.464646464646471. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0066539 s.
# info: [time] Applying Dirichlet BCs took 0.0002071 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 211/10000
# info: 	 residual: 7.972135e-21
#
# info: [time] Linear solver took 0.0049959 s.
# info: Convergence criterion: |dx|=4.5155e+04, |x|=5.5784e+06, |dx|/|x|=8.0946e-03
# info: [time] Iteration #1 took 0.0119201 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.005448 s.
# info: [time] Applying Dirichlet BCs took 0.0001459 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 58/10000
# info: 	 residual: 8.369606e-21
#
# info: [time] Linear solver took 0.0014408 s.
# info: Convergence criterion: |dx|=5.1027e-09, |x|=5.5784e+06, |dx|/|x|=9.1473e-16
# info: [time] Iteration #2 took 0.0070714 s.
# info: [time] Solving process #0 took 0.0190984 s in time step #23
# info: [time] Time step #23 took 0.0205024 s.
# info: [time] Output of timestep 23 took 0.0162028 s.
# info: Time step #24 started. Time: 48.484848484848484. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0058169 s.
# info: [time] Applying Dirichlet BCs took 0.0002062 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 210/10000
# info: 	 residual: 9.683850e-21
#
# info: [time] Linear solver took 0.004932 s.
# info: Convergence criterion: |dx|=4.3227e+04, |x|=5.6197e+06, |dx|/|x|=7.6919e-03
# info: [time] Iteration #1 took 0.0110049 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0054853 s.
# info: [time] Applying Dirichlet BCs took 0.0001313 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 57/10000
# info: 	 residual: 9.451185e-21
#
# info: [time] Linear solver took 0.0013842 s.
# info: Convergence criterion: |dx|=4.4657e-09, |x|=5.6197e+06, |dx|/|x|=7.9464e-16
# info: [time] Iteration #2 took 0.0070376 s.
# info: [time] Solving process #0 took 0.0181524 s in time step #24
# info: [time] Time step #24 took 0.0195057 s.
# info: [time] Output of timestep 24 took 0.0148884 s.
# info: Time step #25 started. Time: 50.505050505050505. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0058217 s.
# info: [time] Applying Dirichlet BCs took 0.0002037 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 210/10000
# info: 	 residual: 8.863273e-21
#
# info: [time] Linear solver took 0.0048971 s.
# info: Convergence criterion: |dx|=4.1457e+04, |x|=5.6594e+06, |dx|/|x|=7.3253e-03
# info: [time] Iteration #1 took 0.0109788 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0056123 s.
# info: [time] Applying Dirichlet BCs took 0.0001284 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 58/10000
# info: 	 residual: 7.465948e-21
#
# info: [time] Linear solver took 0.001484 s.
# info: Convergence criterion: |dx|=4.6316e-09, |x|=5.6594e+06, |dx|/|x|=8.1839e-16
# info: [time] Iteration #2 took 0.0072606 s.
# info: [time] Solving process #0 took 0.0183485 s in time step #25
# info: [time] Time step #25 took 0.0196774 s.
# info: [time] Output of timestep 25 took 0.0145001 s.
# info: Time step #26 started. Time: 52.525252525252526. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0066276 s.
# info: [time] Applying Dirichlet BCs took 0.0002145 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 209/10000
# info: 	 residual: 9.287464e-21
#
# info: [time] Linear solver took 0.004867 s.
# info: Convergence criterion: |dx|=3.9827e+04, |x|=5.6975e+06, |dx|/|x|=6.9901e-03
# info: [time] Iteration #1 took 0.0117756 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0062626 s.
# info: [time] Applying Dirichlet BCs took 0.0001357 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 56/10000
# info: 	 residual: 9.631498e-21
#
# info: [time] Linear solver took 0.0013815 s.
# info: Convergence criterion: |dx|=5.3336e-09, |x|=5.6975e+06, |dx|/|x|=9.3613e-16
# info: [time] Iteration #2 took 0.0078238 s.
# info: [time] Solving process #0 took 0.0197175 s in time step #26
# info: [time] Time step #26 took 0.0210856 s.
# info: [time] Output of timestep 26 took 0.0148055 s.
# info: Time step #27 started. Time: 54.545454545454547. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.005796 s.
# info: [time] Applying Dirichlet BCs took 0.0002026 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 209/10000
# info: 	 residual: 8.610085e-21
#
# info: [time] Linear solver took 0.005005 s.
# info: Convergence criterion: |dx|=3.8320e+04, |x|=5.7342e+06, |dx|/|x|=6.6827e-03
# info: [time] Iteration #1 took 0.0110573 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0056253 s.
# info: [time] Applying Dirichlet BCs took 0.0001416 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 57/10000
# info: 	 residual: 9.298528e-21
#
# info: [time] Linear solver took 0.0014026 s.
# info: Convergence criterion: |dx|=4.6337e-09, |x|=5.7342e+06, |dx|/|x|=8.0808e-16
# info: [time] Iteration #2 took 0.0072184 s.
# info: [time] Solving process #0 took 0.0183927 s in time step #27
# info: [time] Time step #27 took 0.0197286 s.
# info: [time] Output of timestep 27 took 0.0167561 s.
# info: Time step #28 started. Time: 56.565656565656568. Step size: 2.0202020202020203.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0070561 s.
# info: [time] Applying Dirichlet BCs took 0.0002918 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 208/10000
# info: 	 residual: 9.699376e-21
#
# info: [time] Linear solver took 0.0062039 s.
# info: Convergence criterion: |dx|=3.6924e+04, |x|=5.7696e+06, |dx|/|x|=6.3998e-03
# info: [time] Iteration #1 took 0.0136403 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0058218 s.
# info: [time] Applying Dirichlet BCs took 0.0001359 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 56/10000
# info: 	 residual: 9.384690e-21
#
# info: [time] Linear solver took 0.0013666 s.
# ...
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 68/10000
# info: 	 residual: 9.358908e-21
#
# info: [time] Linear solver took 0.0016493 s.
# info: Convergence criterion: |dx|=8.8667e-09, |x|=8.5735e+06, |dx|/|x|=1.0342e-15
# info: [time] Iteration #2 took 0.0073199 s.
# info: [time] Solving process #0 took 0.019152 s in time step #190
# info: [time] Time step #190 took 0.0204799 s.
# info: [time] Output of timestep 190 took 0.0155246 s.
# info: Time step #191 started. Time: 936. Step size: 8.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0061984 s.
# info: [time] Applying Dirichlet BCs took 0.0002363 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 227/10000
# info: 	 residual: 9.471960e-21
#
# info: [time] Linear solver took 0.0052571 s.
# info: Convergence criterion: |dx|=1.0851e+04, |x|=8.5840e+06, |dx|/|x|=1.2641e-03
# info: [time] Iteration #1 took 0.0117627 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0059631 s.
# info: [time] Applying Dirichlet BCs took 0.0001385 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 67/10000
# info: 	 residual: 8.995898e-21
#
# info: [time] Linear solver took 0.0017328 s.
# info: Convergence criterion: |dx|=8.1053e-09, |x|=8.5840e+06, |dx|/|x|=9.4423e-16
# info: [time] Iteration #2 took 0.0078748 s.
# info: [time] Solving process #0 took 0.0197767 s in time step #191
# info: [time] Time step #191 took 0.0212065 s.
# info: [time] Output of timestep 191 took 0.0155408 s.
# info: Time step #192 started. Time: 944. Step size: 8.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0058322 s.
# info: [time] Applying Dirichlet BCs took 0.0001998 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 227/10000
# info: 	 residual: 9.354674e-21
#
# info: [time] Linear solver took 0.0053392 s.
# info: Convergence criterion: |dx|=1.0816e+04, |x|=8.5945e+06, |dx|/|x|=1.2584e-03
# info: [time] Iteration #1 took 0.0114323 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0057847 s.
# info: [time] Applying Dirichlet BCs took 0.0001518 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 69/10000
# info: 	 residual: 7.647629e-21
#
# info: [time] Linear solver took 0.001718 s.
# info: Convergence criterion: |dx|=9.5987e-09, |x|=8.5945e+06, |dx|/|x|=1.1168e-15
# info: [time] Iteration #2 took 0.0077145 s.
# info: [time] Solving process #0 took 0.0192514 s in time step #192
# info: [time] Time step #192 took 0.020626 s.
# info: [time] Output of timestep 192 took 0.0163385 s.
# info: Time step #193 started. Time: 952. Step size: 8.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0064755 s.
# info: [time] Applying Dirichlet BCs took 0.0002006 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 227/10000
# info: 	 residual: 9.210356e-21
#
# info: [time] Linear solver took 0.0055689 s.
# info: Convergence criterion: |dx|=1.0781e+04, |x|=8.6049e+06, |dx|/|x|=1.2529e-03
# info: [time] Iteration #1 took 0.0123173 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0056675 s.
# info: [time] Applying Dirichlet BCs took 0.0001537 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 69/10000
# info: 	 residual: 7.992344e-21
#
# info: [time] Linear solver took 0.0016941 s.
# info: Convergence criterion: |dx|=1.1378e-08, |x|=8.6049e+06, |dx|/|x|=1.3222e-15
# info: [time] Iteration #2 took 0.0075662 s.
# info: [time] Solving process #0 took 0.0200064 s in time step #193
# info: [time] Time step #193 took 0.0213399 s.
# info: [time] Output of timestep 193 took 0.0156824 s.
# info: Time step #194 started. Time: 960. Step size: 8.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.006649 s.
# info: [time] Applying Dirichlet BCs took 0.0002428 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 227/10000
# info: 	 residual: 9.506183e-21
#
# info: [time] Linear solver took 0.0052681 s.
# info: Convergence criterion: |dx|=1.0748e+04, |x|=8.6153e+06, |dx|/|x|=1.2476e-03
# info: [time] Iteration #1 took 0.0122271 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0058398 s.
# info: [time] Applying Dirichlet BCs took 0.0001389 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 68/10000
# info: 	 residual: 9.542693e-21
#
# info: [time] Linear solver took 0.00168 s.
# info: Convergence criterion: |dx|=9.1716e-09, |x|=8.6153e+06, |dx|/|x|=1.0646e-15
# info: [time] Iteration #2 took 0.0077051 s.
# info: [time] Solving process #0 took 0.019959 s in time step #194
# info: [time] Time step #194 took 0.0212795 s.
# info: [time] Output of timestep 194 took 0.0147964 s.
# info: Time step #195 started. Time: 968. Step size: 8.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0059641 s.
# info: [time] Applying Dirichlet BCs took 0.0002006 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 227/10000
# info: 	 residual: 9.183359e-21
#
# info: [time] Linear solver took 0.0052841 s.
# info: Convergence criterion: |dx|=1.0716e+04, |x|=8.6256e+06, |dx|/|x|=1.2424e-03
# info: [time] Iteration #1 took 0.011518 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0070975 s.
# info: [time] Applying Dirichlet BCs took 0.0001551 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 67/10000
# info: 	 residual: 8.794042e-21
#
# info: [time] Linear solver took 0.0016507 s.
# info: Convergence criterion: |dx|=8.7528e-09, |x|=8.6256e+06, |dx|/|x|=1.0147e-15
# info: [time] Iteration #2 took 0.0089601 s.
# info: [time] Solving process #0 took 0.0206053 s in time step #195
# info: [time] Time step #195 took 0.0220217 s.
# info: [time] Output of timestep 195 took 0.0155011 s.
# info: Time step #196 started. Time: 976. Step size: 8.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.005971 s.
# info: [time] Applying Dirichlet BCs took 0.0002007 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 227/10000
# info: 	 residual: 9.051410e-21
#
# info: [time] Linear solver took 0.0067877 s.
# info: Convergence criterion: |dx|=1.0685e+04, |x|=8.6360e+06, |dx|/|x|=1.2373e-03
# info: [time] Iteration #1 took 0.0130153 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0057422 s.
# info: [time] Applying Dirichlet BCs took 0.0001452 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 69/10000
# info: 	 residual: 9.750657e-21
#
# info: [time] Linear solver took 0.0016795 s.
# info: Convergence criterion: |dx|=9.4751e-09, |x|=8.6360e+06, |dx|/|x|=1.0972e-15
# info: [time] Iteration #2 took 0.0076084 s.
# info: [time] Solving process #0 took 0.0207415 s in time step #196
# info: [time] Time step #196 took 0.0220635 s.
# info: [time] Output of timestep 196 took 0.0150373 s.
# info: Time step #197 started. Time: 984. Step size: 8.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0059973 s.
# info: [time] Applying Dirichlet BCs took 0.0002004 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 227/10000
# info: 	 residual: 9.299989e-21
#
# info: [time] Linear solver took 0.0053112 s.
# info: Convergence criterion: |dx|=1.0655e+04, |x|=8.6463e+06, |dx|/|x|=1.2323e-03
# info: [time] Iteration #1 took 0.0115822 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0053604 s.
# info: [time] Applying Dirichlet BCs took 0.000133 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 67/10000
# info: 	 residual: 9.172209e-21
#
# info: [time] Linear solver took 0.0016376 s.
# info: Convergence criterion: |dx|=9.9708e-09, |x|=8.6463e+06, |dx|/|x|=1.1532e-15
# info: [time] Iteration #2 took 0.0071646 s.
# info: [time] Solving process #0 took 0.01887 s in time step #197
# info: [time] Time step #197 took 0.0202112 s.
# info: [time] Output of timestep 197 took 0.0148046 s.
# info: Time step #198 started. Time: 992. Step size: 8.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0059686 s.
# info: [time] Applying Dirichlet BCs took 0.0002027 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 227/10000
# info: 	 residual: 8.657932e-21
#
# info: [time] Linear solver took 0.0052595 s.
# info: Convergence criterion: |dx|=1.0626e+04, |x|=8.6565e+06, |dx|/|x|=1.2275e-03
# info: [time] Iteration #1 took 0.0114957 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0055404 s.
# info: [time] Applying Dirichlet BCs took 0.0001661 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 68/10000
# info: 	 residual: 9.491761e-21
#
# info: [time] Linear solver took 0.0016567 s.
# info: Convergence criterion: |dx|=1.0281e-08, |x|=8.6565e+06, |dx|/|x|=1.1877e-15
# info: [time] Iteration #2 took 0.007427 s.
# info: [time] Solving process #0 took 0.0189485 s in time step #198
# info: [time] Time step #198 took 0.0203273 s.
# info: [time] Output of timestep 198 took 0.0154933 s.
# info: Time step #199 started. Time: 1000. Step size: 8.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.005801 s.
# info: [time] Applying Dirichlet BCs took 0.0002062 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 227/10000
# info: 	 residual: 8.560372e-21
#
# info: [time] Linear solver took 0.0053042 s.
# info: Convergence criterion: |dx|=1.0598e+04, |x|=8.6668e+06, |dx|/|x|=1.2229e-03
# info: [time] Iteration #1 took 0.0113667 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0059131 s.
# info: [time] Applying Dirichlet BCs took 0.0001512 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 69/10000
# info: 	 residual: 9.805927e-21
#
# info: [time] Linear solver took 0.0016812 s.
# info: Convergence criterion: |dx|=1.0825e-08, |x|=8.6668e+06, |dx|/|x|=1.2491e-15
# info: [time] Iteration #2 took 0.0077977 s.
# info: [time] Solving process #0 took 0.0192778 s in time step #199
# info: [time] Time step #199 took 0.0206354 s.
# info: [time] Output of timestep 199 took 0.0149321 s.
# info: The whole computation of the time stepping took 199 steps, in which
# 	 the accepted steps are 199, and the rejected steps are 0.
#
# info: [time] Execution took 7.46127 s.
# info: OGS terminated on 2026-03-27 12:07:03+0100.

# %% [markdown]
# ## Results and visualisation

# %% [markdown]
# ### Post-processing

# %%
pvd_path0 = Path("_out/Line_source.pvd")
ms0 = ot.MeshSeries(pvd_path0)
pressure=ot.variables.pressure
pressure= pressure.replace(output_unit="MPa")

# %%
y=-20
r_st=0.038 #equating the rgeo analytical
r_en=15

coords=np.array(np.geomspace([r_st,y,1e-18],[r_en,y,1e-18],6).round(3)) #extracting along x linearly
ms_probes0 = ms0.extract_probe(ms0,points=coords)

labels0 = [f"r={pt[0]:>5.3f}, y={y}" for pt in coords]

diff0 = pwr0 - ms_probes0['pressure']
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [00:03<00:00, 53.27it/s]

# %% [markdown]
# ### Analytical and Numerical OGS comparison

# %%
fig5, axs= plt.subplots(nrows=1, ncols=2,figsize=[15,6], sharex=True)
ot.plot.line(ms_probes0,"time", pressure,ax=axs[0], color='k',fontsize=18,label=labels0)
axs[0].plot(t, pwr0/1e6,color='tab:red', label=line_labels0) 
axs[1].plot(t, diff0/1e6, label=line_labels0)

fig5.suptitle("Line-source analytical rf-nfb,   - Numerical OGS Neumann Line-source") 
axs[0].set_title("Resuls by distance (radii)")
axs[1].set_title("Difference analytical-OGS")

axs[1].set_xlabel("time / s")
axs[1].set_ylabel("diff / MPa")

axs[0].legend()
axs[1].legend()
axs[1].grid()
plt.tight_layout()

plt.show()
#fig5.savefig(f"lsrfn_fb_2D_Ca.pdf",format='pdf')

# %%
#Pwd finite source vs OGS 
pw2=pwr2[0:,-1] #las re in evaluaiton same cube size
ms_probes0_w=ms_probes0['pressure'][0:,0]
timeogs=ms0.timevalues
diff2 = pw2-ms_probes0_w

fig6, axs= plt.subplots(nrows=1, ncols=2,figsize=[15,6], sharex=True)
axs[0].plot(timeogs,ms_probes0_w/1e6, color='k',label=labels0[0])
axs[0].plot(t, pw2/1e6,color='tab:red', label=line_labels0[0]) 
axs[1].plot(t, diff2/1e6, label=line_labels0[0])

fig6.suptitle("Finite-source analytical rf-nfb wellbore  - Numerical OGS Neumann Line-source") 
axs[0].set_title("Results at wellbore")
axs[1].set_title("Difference analytical-OGS")

axs[0].set_xlabel("time / s")
axs[0].set_ylabel("Pressure / MPa")
axs[1].set_xlabel("time / s")
axs[1].set_ylabel("diff / MPa")

axs[0].legend()
axs[0].grid()
axs[1].legend()
axs[1].grid()
plt.tight_layout()

plt.show()
#fig6.savefig(f"fsrfn_fb_2D_Ca.pdf",format='pdf')

# %% [markdown]
# # STIMTEC Example

# %% [markdown]
# ## Path 2

# %%
OGS_PATH = None

if OGS_PATH is not None:
    os.environ["OGS_BIN_PATH"] = OGS_PATH
OUT_DIR = Path(os.environ.get("OGS_TESTRUNNER_OUT_DIR", "_out_2"))
MESH_DIR = OUT_DIR / "mesh"
shutil.rmtree(OUT_DIR, ignore_errors=True)
MESH_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Line/finite-source and step rate

# %% [markdown]
# ### Pre-procesing and preparing data

# %%
cwd=Path.cwd()
newpath=cwd/"STIMTEC_example"
TESTSR= 'BH10_20180718_40.6'
dataex=pd.read_csv(newpath/"BH10_20180718_40.6.csv",sep=",",header=0)

# %%
#visualising full data set
#storage correction puphole
su=1/32.664 #(m3/Pa)
dp_dt=np.gradient(dataex['Pint_downhole [MPa]'],dataex['Zeit [s]'])
dataex['Q_downhole [lpm]']=dataex['Q_uphole [lpm]']+dp_dt*su

fig7, ax=plt.subplots()

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / MPa, flowrate / lpm")
plt.title(f"test: {TESTSR}")

ax.plot(dataex['Zeit [s]'],dataex['Pint_downhole [MPa]'],label="Pint_downhole [MPa]")
ax.plot(dataex['Zeit [s]'],dataex['Q_downhole [lpm]'],label="Q_downhole [lpm]")
plt.legend()
plt.show()

# %%
#isolating Step-rate and preparing curve

mask = (dataex['Zeit [s]'] > 1750) & (dataex['Zeit [s]'] <2670)
dataex_f = dataex.loc[mask, :].copy()
dataex_f = dataex_f.reset_index(drop=True)

dataex_f['Q_downhole [lpm]_s']=scale_and_smooth(dataex_f['Q_downhole [lpm]'])

steps_=pickings(dataex_f['Q_downhole [lpm]_s'],40,20)
print('steps','\t', len(steps_))

fig8, ax=plt.subplots()

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / MPa, flowrate / lpm")
plt.title(f"test: {TESTSR}, steps")

ax.plot(dataex_f['Zeit [s]'],dataex_f['Pint_downhole [MPa]'],label="P int d")
for i in range (len(steps_)):
     ax.axvline(x=dataex_f.loc[steps_[i,0],'Zeit [s]'],ls="--",color="tab:red")
ax.plot(dataex_f['Zeit [s]'],dataex_f['Q_downhole [lpm]'],label="Q downhole")
ax.plot(dataex_f['Zeit [s]'],dataex_f['Q_downhole [lpm]_s'],label="Q downhole_smoothed")

plt.legend()
plt.show()
#fig8.savefig(f"{TESTSR}_marks.pdf",format='pdf')
# Out:
# steps 	 7

# %%
#protocol
pr=pd.DataFrame(data=steps_,
                      index = np.arange(len(steps_)),
                      columns=['index','qs'])
protocol={'index':0,'qs':dataex_f['Q_downhole [lpm]_s'].values[0],'T_s':dataex_f['Zeit [s]'].values[0]}
pr["T_s"]=dataex_f.loc[steps_[:,0].astype(int),'Zeit [s]'].values
protocol=pd.concat([pd.DataFrame(protocol,index=[0]),pr],axis=0)
protocol.reset_index(drop=True, inplace=True)
protocol['qs']=-protocol['qs']/60000 #injection is negative flow

# %% [markdown]
# ### Finite-source Analytical running

# %%
#data 
#average parameters from PPT
Dqp= 6.21e-1 #m**2/s
Tqp= 9.52E-07 #m**2/s
Sqp=1.53E-06  #-
re=8.5       # 8.63 m in reference
h=0.7         # m taken as interval length

c_t=Sqp/(1000*9.8*1.7*0.03)  # Pa-1
c_t=float(f"{c_t:.2e}")
kcal=(Tqp*1e-3)/(1000*9.8*1.7) #m**2
kcal=float(f"{kcal:.2e}")
print(f'Estimated total compressibility: {c_t},{'\n'}Estimated permeability {kcal}')

ddict={"p_i":86316.0,
       "mu":1e-3 ,
       "B":1,
       "por":0.030,
       "c_t":c_t ,
       "r_w":0.038,
       'h': h
      }

delta_t=dataex_f['Zeit [s]'].values
tp=protocol['T_s'].values
q_array=protocol['qs'].values

rinv=np.sqrt(kcal*(tp[-1]-tp[0])/(ddict['por']*ddict['mu']*ddict['c_t']))
print("Investigation radius (m): ",f"{rinv:.2f}",'\n','"Unperturbed" threshold (m): ', f"{4*rinv:.2f}")
# Out:
# Estimated total compressibility: 3.06e-09,
# Estimated permeability 5.71e-14
# Investigation radius (m):  21.85
#  "Unperturbed" threshold (m):  87.41

# %%
#evaluating k around reference
re=re
rw=ddict['r_w']
am= find_roots_am(rw, re,n_roots=1000)

r_val0=ddict['r_w'] #at wellbore face
k_val0= np.geomspace(6e-14, 5e-13, 5) 

pwsr0= step_rate_r(pwd_fsrf_fb, delta_t, tp, q_array, ddict, k_val0, r_val0,re,am)

# %%
#evaluating k around reference
line_labels9 = [f"k = {val:>5.2e} m^2" for val in k_val0]

fig9, ax=plt.subplots()

ax.plot(delta_t, pwsr0/1e6, label=line_labels9)  
ax.plot(dataex_f['Zeit [s]'],dataex_f['Pint_downhole [MPa]'],label="P int d", ls="--")

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / MPa")
plt.title(f"test: {TESTSR}, k-values, re={re} m")

plt.legend()
plt.show()

# %%
#evaluating re around reference
re1=np.geomspace(8,24,5).round(2) #range of re in reference wellinj to wellmon distance.
rw=ddict['r_w']
am1= find_roots_am(rw, re1,n_roots=1000)

r_val1=ddict['r_w'] #at wellbore face
k_val1= 5.5e-14

pwsr1= step_rate_r(pwd_fsrf_fb, delta_t, tp, q_array, ddict, k_val1, r_val1,re1,am1)

line_labels10 = [f"re = {val:>5.2f} m" for val in re1]
fig10, ax=plt.subplots()

ax.plot(delta_t, pwsr1/1e6, label=line_labels10)   
ax.plot(dataex_f['Zeit [s]'],dataex_f['Pint_downhole [MPa]'],label="P int d", ls="--")

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / MPa")
plt.title(f"test: {TESTSR}, r-values, k={k_val1} m^2")

plt.legend()
plt.show()

# %%
#evaluating best references k and re
re2=14  #range of best re
rw=ddict['r_w']
am2= find_roots_am(rw, re2,n_roots=1000)

r_val2=ddict['r_w'] #at wellbore face
k_val2= k_val1

pwsr2= step_rate_r(pwd_fsrf_fb, delta_t, tp, q_array, ddict, k_val2, r_val2,re2,am2)

fig11, ax=plt.subplots()

ax.plot(delta_t, pwsr2/1e6, label=f're = {re2:.2f} m') 
ax.plot(dataex_f['Zeit [s]'],dataex_f['Pint_downhole [MPa]'],label="P int d", ls="--")

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / MPa")
plt.title(f"test: {TESTSR}, k={k_val2} m^2")

plt.legend()
plt.show()

# %% [markdown]
# ### Plot Report finite-source

# %%
fig12, axs= plt.subplots(nrows=3, ncols=1,figsize=[6,10], sharex=True)


axs[0].plot(delta_t, pwsr0/1e6, label=line_labels9)
axs[0].set_title(f"test: {TESTSR}, k-values, re={re} m")

axs[1].plot(delta_t, pwsr1/1e6, label=line_labels10)
axs[1].set_title(f"test: {TESTSR}, r-values, k={k_val1} m^2")

axs[2].plot(delta_t, pwsr2/1e6, label=f're = {re2:.2f} m') 
axs[2].set_title(f"test: {TESTSR}, k={k_val2} m^2")
axs[2].set_xlabel("time / s")

for i in range (0,3):
    axs[i].plot(dataex_f['Zeit [s]'],dataex_f['Pint_downhole [MPa]'],label="P int d", ls="--")
    axs[i].set_ylabel("Pressure / MPa")
    axs[i].grid()
    axs[i].legend()

plt.tight_layout()
plt.show()
#fig12.savefig(f"fsrfa_fb_2D_{TESTSR}.pdf",format='pdf')

# %% [markdown]
# ### Line-source Analytical running

# %% [markdown]
# With parameters adjusted a wellboreface, $r_\mathrm{w}$ with function of finite source. Now the evaluation carries $r$ variation with line source.

# %%
#evaluating best references k and re with varying r to re
re3=re2  #range of best re
rw=ddict['r_w']

r_val3=np.geomspace(ddict['r_w'],re2,5).round(3) 
k_val3= k_val2
print(f're:{re3} m {'\n'} k:{k_val3} m^2 {'\n'} r:{r_val3} m')

pwsr3= step_rate_r(pd_lsrf_fb, delta_t, tp, q_array, ddict, k_val3, r_val3,re3)

line_labels13 = [f"r = {val:>5.2f} m" for val in r_val3]
fig13, ax=plt.subplots()

ax.plot(delta_t, pwsr3/1e6, label=line_labels13)
ax.plot(dataex_f['Zeit [s]'],dataex_f['Pint_downhole [MPa]'],label="P int d", ls="--")

ax.set_xlabel("time / s")
ax.set_ylabel("Pressure / MPa")
plt.title(f"test: {TESTSR}, r-values, k={k_val3} m^2, re={re3} m")

plt.legend()
plt.tight_layout()
plt.grid()
plt.show()
#fig13.savefig(f"lsrfa_fb_2D_{TESTSR}.pdf",format='pdf') #report figure
# Out:
# re:14 m
#  k:5.5e-14 m^2
#  r:[ 0.038  0.166  0.729  3.196 14.   ] m

# %% [markdown]
# ## Line/Finite-source Numerical OGS

# %% [markdown]
# ### Meshing 2D Finite-Source

# %%
MSH_FILE = MESH_DIR / "symmetric_cylinder_2D.msh"

r_well=ddict['r_w']
thickness=ddict.get('h', 1.0)  
mesh_size=thickness/4

create_scylindre_mesh( 
        MSH_FILE,
        radius= re3,
        thickness= thickness,
        mesh_size= mesh_size,        #ideal 1/2 of thickness for symmetrical radial application
        r_well= r_well,      # Starting radius (0 for line, >0 for finite well radius in Neumann BC)
        refine_size= 0.05,     # standard 0.1 
        center_y= -40.6
        )

meshes = ot.meshes_from_gmsh(MSH_FILE, log=False)
for name, mesh in meshes.items():
    vtu_path = MESH_DIR / f"rectangle_{name}.vtu"
    pv.save_meshio(vtu_path, mesh)
    print(f"Saved {vtu_path}")
# Out:
# Saved _out_2\mesh\rectangle_domain.vtu
# Saved _out_2\mesh\rectangle_physical_group_top.vtu
# Saved _out_2\mesh\rectangle_physical_group_boundary_R.vtu
# Saved _out_2\mesh\rectangle_physical_group_bottom.vtu
# Saved _out_2\mesh\rectangle_physical_group_well.vtu
# Saved _out_2\mesh\rectangle_physical_group_domain.vtu

# %%
fig14 = meshes["domain"].plot_contourf(
    "MaterialIDs",
    figsize=(8, 6),
    dpi=100,
    cmap="tab20",
    alpha=0.3,
    linewidth=0,
)
ax = fig14.axes[0]
for i, (name, mesh) in enumerate(sorted(meshes.items())):
    if mesh.area:  
        continue
    ls, marker = ("-", "") if "boundary" in name else ("-", "o")
    ot.plot.line(
        mesh,
        ax=ax,
        color=f"C{i}",
        lw=2,
        ls=ls,
        marker=marker,
        markersize=8,
        label=name,
    )
ax.set_xlabel('r / m')
ax.legend(ncol=2, fontsize=10, frameon=False)
plt.show()

# %% [markdown]
# ### PRJ file pre-procesing

# %%
k_ref= k_val3 
ct_ref= ddict["c_t"]*ddict['por'] #OGS storage is scale down by por analytical
print(f'step_rate base {q_array}') #in analytical drawndown positive 

q_fact=-1/(2*np.pi*r_well*ddict['h']) #factor for OGS q*q_fact sign->inj: (+), (-); changing to flux based upon r_well building mesh
# Out:
# step_rate base [-4.99798388e-08 -9.31177407e-06 -1.90106980e-05 -3.41504329e-05
#  -6.76589529e-05 -1.01353107e-04 -1.33181916e-04 -2.52184752e-07]

# %%
PROJECT_BASENAME = "Line_source"
PROJECT_NEW=TESTSR

prj_in = Path(f"{PROJECT_BASENAME}.prj")
prj_out = OUT_DIR/ f"{PROJECT_NEW}_updated.prj"

prj = ot.Project(input_file=prj_in, output_file=prj_out)

# %%
root = prj.tree.getroot()
mesh_nodes = root.findall("./meshes/mesh")

if mesh_nodes:
    for mesh_node in mesh_nodes:
        is_axial = mesh_node.get("axially_symmetric")
        
        if is_axial != "true":
            mesh_node.set("axially_symmetric", "true")
            print(f"Added axial symmetry to: {mesh_node.text}")
        else:
            print(f"Axial symmetry already active for: {mesh_node.text}")
else:
    print("Error: No <mesh> tags found in the <meshes> section.")
# Out:
# Added axial symmetry to: rectangle_domain.vtu
# Added axial symmetry to: rectangle_physical_group_bottom.vtu
# Added axial symmetry to: rectangle_physical_group_top.vtu
# Added axial symmetry to: rectangle_physical_group_well.vtu
# Added axial symmetry to: rectangle_physical_group_boundary_R.vtu

# %%
boundary_condition='no_flow_boundary' #options: infinite, no_flow_boundary, pressure_boundary
target_mesh = "rectangle_physical_group_boundary_R"

def mesh_condition(boundary,target,ddict=ddict):
    xpath=f"./process_variables/process_variable/boundary_conditions/boundary_condition[mesh='{target}']/type"
    bc={"infinite":'Dirichlet',"no_flow_boundary":'Neumann', "pressure_boundary":'Dirichlet'}

    if boundary in bc:
        prj.replace_text(bc[boundary], xpath=xpath)
        print(f"Updated {target} to {bc[boundary]}")
        
        if boundary=='no_flow_boundary':
            prj.replace_parameter_value(name="pi_bd", value=0)
            value_r=0
        else:
            prj.replace_parameter_value(name="pi_bd", value=ddict["p_i"]) 
            value_r=ddict["p_i"]
        print(f"Updated {target} value to {value_r}") 
    else:
        print(f"Error: '{boundary}' is not a valid boundary option.") 

try:
    mesh_condition(boundary_condition,target_mesh)
    
    prj.replace_parameter_value(name="p0", value=ddict["p_i"])
    prj.replace_parameter_value(name="q_in", value=v_in)

    mid=0
    prj.replace_phase_property_value(mediumid=mid, phase="AqueousLiquid", name="viscosity", value=ddict["mu"])
    
    prj.replace_medium_property_value(mediumid=mid, name="porosity", value=ddict["por"])
    prj.replace_medium_property_value(mediumid=mid, name="permeability", value=k_ref)
    prj.replace_medium_property_value(mediumid=mid, name="storage", value= ct_ref)

    print("media/properties, Parameters updated")
except Exception as e:
    print(f"Error occurred: {e}")
# Out:
# Updated rectangle_physical_group_boundary_R to Neumann
# Updated rectangle_physical_group_boundary_R value to 0
# media/properties, Parameters updated

# %%
last_t=dataex_f.loc[dataex_f.tail(1).index.values.astype(int),'Zeit [s]':'Q_downhole [lpm]']
last_t['Q_downhole [lpm]']=last_t['Q_downhole [lpm]']/60000
last_t=last_t.values.flatten().tolist() 
print(f'"Last-step" {last_t}')

param_name = "q_in" #inlet flow

def create_sr_ogs(T,q,data,factor=q_fact,var="t"): #factor carries the convention: production = q*factor (-), injection (+)
        
    q_scaled = q * factor
    q_last_scaled = data[1] * factor 
    
    q_list = q_scaled.tolist()
    q_list.append(q_last_scaled)
    
    T_list = T.tolist()
    T_list.append(data[0])
        
    parts = [f"{var} < {T_list[i+1]:g} ? {q_list[i]:.6g} :" for i in range(0, len(T_list)-1)]
    
    return "(" + "\n           ".join(parts) + f"\n           {q_list[-1]:.6g})",T_list
    
def set_adaptive_stepping(prj, t_start, t_end, initial_dt=1, min_dt=0.5,max_dt=10):
    try:
        prj.remove_element(xpath="./time_loop/processes/process/time_stepping")
    except:
        pass 
        
    iterations = "1 3 5 8 10"
    multipliers = "1.5 1.2 1.0 0.8 0.5"
    
    prj.add_block("time_stepping", 
                  parent_xpath="./time_loop/processes/process", 
                  taglist=[
                      "type",
                      "t_initial", 
                      "t_end", 
                      "initial_dt", 
                      "minimum_dt", 
                      "maximum_dt", 
                      "number_iterations",
                      "multiplier"
                          ],
                  textlist=["IterationNumberBasedTimeStepping",
                            str(t_start),
                            str(t_end),
                            str(initial_dt),
                            str(min_dt),
                            str(max_dt),
                            iterations,
                            multipliers
                           ]
                  )
    
    print(f"Adaptive stepping set: {t_start} to {t_end} (Max Δt: {max_dt})")

try:  
    root = prj.tree.getroot() # Access the underlying ElementTree
    param_node = root.find(f".//parameters/parameter[name='{param_name}']")
    value_tag = param_node.find("value")
    if value_tag is not None:
         param_node.remove(value_tag)
    
    n_type = prj.replace_text(
        "Function", xpath=f".//parameters/parameter[name='{param_name}']/type"
    )
    
    n_expr,Times = create_sr_ogs(tp,q_array,last_t)
    
    prj.add_element(
        parent_xpath=f".//parameters/parameter[name='{param_name}']", 
        tag="expression", 
        text=n_expr
    )
    
    print("flow_expression", n_expr)
    
    #timestepping calculations 
    max_dt=10
    set_adaptive_stepping(prj, Times[0], Times[-1], max_dt=max_dt)

    #out and prefix
    outsteps=1 #10 at convenience
    prefix= TESTSR
    
    prj.replace_text("1",
                     xpath="./time_loop/output/timesteps/pair/repeat")
    prj.replace_text(outsteps, #resolution of stepping
                    xpath="./time_loop/output/timesteps/pair/each_steps")
    prj.replace_text(prefix, 
                     xpath="./time_loop/output/prefix")
    
    print("ouput_res: ", outsteps,'\n','prefix:',prefix )
    
except Exception as e:
    
    print(f"Error occurred: {e}")

prj.write_input()
print('\n', f"prj update in {prj_out} as {PROJECT_NEW}_updated.prj")
# Out:
# "Last-step" [2669.809, 0.006152, 9.957901053148818e-08]
# flow_expression (t < 1794.21 ? 2.99043e-07 :
#            t < 1909.81 ? 5.57148e-05 :
#            t < 2079.81 ? 0.000113746 :
#            t < 2160.01 ? 0.000204331 :
#            t < 2330.81 ? 0.000404822 :
#            t < 2430.41 ? 0.000606423 :
#            t < 2517.81 ? 0.000796863 :
#            t < 2669.81 ? 1.50889e-06 :
#            -0.0368091)
# Adaptive stepping set: 1750.009 to 2669.809 (Max Δt: 10)
# ouput_res:  1
#  prefix: BH10_20180718_40.6
#
#  prj update in _out_2\BH10_20180718_40.6_updated.prj as BH10_20180718_40.6_updated.prj

# %% [markdown]
# ### Running OGS

# %%
# !ogs ./_out_2/BH10_20180718_40.6_updated.prj -m ./_out_2/mesh -o ./_out_2
# Out:
# info: This is OpenGeoSys-6 version 6.5.5.
# info: OGS started on 2026-03-27 12:07:41+0100.
# warning: OMP_NUM_THREADS is not set, falling back to: 16
# info: Eigen use 16 threads
# info: Reading project file _out_2\BH10_20180718_40.6_updated.prj.
# info: readRasters ...
# info: readRasters done
# info: ConstantParameter: p0
# info: ConstantParameter: p_tb
# info: ConstantParameter: pi_bd
# info: ConstantParameter: constant_porosity_parameter
# info: FunctionParameter: q_in
# info: No source terms for process variable 'pressure' found.
# info: Initialize processes.
# info: Time step #0 started. Time: 1750.009. Step size: 0.
# info: [time] Output of timestep 0 took 0.0074067 s.
# info: Time step #0 took 0.0084004 s.
# info: OpenGeoSys is now initialized.
# info: OGS started on 2026-03-27 12:07:41+0100.
# info: Solve processes.
# info: Time step #1 started. Time: 1751.009. Step size: 1.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0029724 s.
# info: [time] Applying Dirichlet BCs took 0.0001037 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 174/10000
# info: 	 residual: 9.183537e-21
#
# info: [time] Linear solver took 0.0021278 s.
# info: Convergence criterion: |dx|=4.5104e+03, |x|=2.2547e+06, |dx|/|x|=2.0004e-03
# info: [time] Iteration #1 took 0.0052903 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0017142 s.
# info: [time] Applying Dirichlet BCs took 3.97e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 91/10000
# info: 	 residual: 8.983689e-21
#
# info: [time] Linear solver took 0.0007473 s.
# info: Convergence criterion: |dx|=2.5307e-09, |x|=2.2547e+06, |dx|/|x|=1.1224e-15
# info: [time] Iteration #2 took 0.0025165 s.
# info: [time] Solving process #0 took 0.0078905 s in time step #1
# info: [time] Time step #1 took 0.0083416 s.
# info: [time] Output of timestep 1 took 0.0063214 s.
# info: Time step #2 started. Time: 1752.509. Step size: 1.5.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0019777 s.
# info: [time] Applying Dirichlet BCs took 5.71e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 175/10000
# info: 	 residual: 6.578130e-21
#
# info: [time] Linear solver took 0.0014122 s.
# info: Convergence criterion: |dx|=1.5972e+03, |x|=2.2557e+06, |dx|/|x|=7.0810e-04
# info: [time] Iteration #1 took 0.0034906 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0017333 s.
# info: [time] Applying Dirichlet BCs took 3.85e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 109/10000
# info: 	 residual: 9.294734e-21
#
# info: [time] Linear solver took 0.0008958 s.
# info: Convergence criterion: |dx|=2.5822e-09, |x|=2.2557e+06, |dx|/|x|=1.1447e-15
# info: [time] Iteration #2 took 0.0026854 s.
# info: [time] Solving process #0 took 0.0061963 s in time step #2
# info: [time] Time step #2 took 0.0066338 s.
# info: [time] Output of timestep 2 took 0.0061382 s.
# info: Time step #3 started. Time: 1754.759. Step size: 2.25.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0018692 s.
# info: [time] Applying Dirichlet BCs took 4.99e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 181/10000
# info: 	 residual: 6.671229e-21
#
# info: [time] Linear solver took 0.0014792 s.
# info: Convergence criterion: |dx|=1.1054e+03, |x|=2.2564e+06, |dx|/|x|=4.8991e-04
# info: [time] Iteration #1 took 0.0034344 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0016974 s.
# info: [time] Applying Dirichlet BCs took 3.95e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 129/10000
# info: 	 residual: 6.878592e-21
#
# info: [time] Linear solver took 0.0010524 s.
# info: Convergence criterion: |dx|=6.9808e-09, |x|=2.2564e+06, |dx|/|x|=3.0938e-15
# info: [time] Iteration #2 took 0.0028065 s.
# info: [time] Solving process #0 took 0.0062591 s in time step #3
# info: [time] Time step #3 took 0.0067087 s.
# info: [time] Output of timestep 3 took 0.0067635 s.
# info: Time step #4 started. Time: 1758.134. Step size: 3.375.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0019576 s.
# info: [time] Applying Dirichlet BCs took 5.08e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 184/10000
# info: 	 residual: 8.288882e-21
#
# info: [time] Linear solver took 0.0015243 s.
# info: Convergence criterion: |dx|=9.3427e+02, |x|=2.2571e+06, |dx|/|x|=4.1393e-04
# info: [time] Iteration #1 took 0.0035767 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0018502 s.
# info: [time] Applying Dirichlet BCs took 4.91e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 142/10000
# info: 	 residual: 8.474708e-21
#
# info: [time] Linear solver took 0.0011598 s.
# info: Convergence criterion: |dx|=9.2339e-09, |x|=2.2571e+06, |dx|/|x|=4.0911e-15
# info: [time] Iteration #2 took 0.0030918 s.
# info: [time] Solving process #0 took 0.006687 s in time step #4
# info: [time] Time step #4 took 0.0071303 s.
# info: [time] Output of timestep 4 took 0.0067555 s.
# info: Time step #5 started. Time: 1763.1965. Step size: 5.0625.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0019178 s.
# info: [time] Applying Dirichlet BCs took 4.99e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 189/10000
# info: 	 residual: 7.592301e-21
#
# info: [time] Linear solver took 0.0015335 s.
# info: Convergence criterion: |dx|=8.6534e+02, |x|=2.2577e+06, |dx|/|x|=3.8328e-04
# info: [time] Iteration #1 took 0.0035358 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0016222 s.
# info: [time] Applying Dirichlet BCs took 3.82e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 147/10000
# info: 	 residual: 9.017827e-21
#
# info: [time] Linear solver took 0.0011853 s.
# info: Convergence criterion: |dx|=9.5646e-09, |x|=2.2577e+06, |dx|/|x|=4.2364e-15
# info: [time] Iteration #2 took 0.0028594 s.
# info: [time] Solving process #0 took 0.0064119 s in time step #5
# info: [time] Time step #5 took 0.0068467 s.
# info: [time] Output of timestep 5 took 0.0062827 s.
# info: Time step #6 started. Time: 1770.79025. Step size: 7.59375.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0018746 s.
# info: [time] Applying Dirichlet BCs took 5.08e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 192/10000
# info: 	 residual: 8.419919e-21
#
# info: [time] Linear solver took 0.0015601 s.
# info: Convergence criterion: |dx|=8.4340e+02, |x|=2.2584e+06, |dx|/|x|=3.7345e-04
# info: [time] Iteration #1 took 0.0035218 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.001625 s.
# info: [time] Applying Dirichlet BCs took 3.73e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 153/10000
# info: 	 residual: 6.382324e-21
#
# info: [time] Linear solver took 0.0012282 s.
# info: Convergence criterion: |dx|=1.2686e-08, |x|=2.2584e+06, |dx|/|x|=5.6174e-15
# info: [time] Iteration #2 took 0.0029049 s.
# info: [time] Solving process #0 took 0.0064429 s in time step #6
# info: [time] Time step #6 took 0.0068749 s.
# info: [time] Output of timestep 6 took 0.0063943 s.
# info: Time step #7 started. Time: 1780.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0019095 s.
# info: [time] Applying Dirichlet BCs took 5.13e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 193/10000
# info: 	 residual: 9.808217e-21
#
# info: [time] Linear solver took 0.0016031 s.
# info: Convergence criterion: |dx|=7.7228e+02, |x|=2.2591e+06, |dx|/|x|=3.4186e-04
# info: [time] Iteration #1 took 0.0035964 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0016842 s.
# info: [time] Applying Dirichlet BCs took 3.98e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 156/10000
# info: 	 residual: 7.711270e-21
#
# info: [time] Linear solver took 0.0012568 s.
# info: Convergence criterion: |dx|=1.6936e-08, |x|=2.2591e+06, |dx|/|x|=7.4970e-15
# info: [time] Iteration #2 took 0.0029959 s.
# info: [time] Solving process #0 took 0.0066082 s in time step #7
# info: [time] Time step #7 took 0.0070461 s.
# info: [time] Output of timestep 7 took 0.0061353 s.
# info: Time step #8 started. Time: 1790.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0019527 s.
# info: [time] Applying Dirichlet BCs took 5.11e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 204/10000
# info: 	 residual: 8.510325e-21
#
# info: [time] Linear solver took 0.0016568 s.
# info: Convergence criterion: |dx|=5.9815e+02, |x|=2.2596e+06, |dx|/|x|=2.6471e-04
# info: [time] Iteration #1 took 0.0036976 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0016274 s.
# info: [time] Applying Dirichlet BCs took 3.75e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 156/10000
# info: 	 residual: 9.122446e-21
#
# info: [time] Linear solver took 0.0012618 s.
# info: Convergence criterion: |dx|=7.6194e-09, |x|=2.2596e+06, |dx|/|x|=3.3720e-15
# info: [time] Iteration #2 took 0.0029427 s.
# info: [time] Solving process #0 took 0.0066576 s in time step #8
# info: [time] Time step #8 took 0.007088 s.
# info: [time] Output of timestep 8 took 0.0067775 s.
# info: Time step #9 started. Time: 1800.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0019291 s.
# info: [time] Applying Dirichlet BCs took 5.02e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 302/10000
# info: 	 residual: 9.811941e-21
#
# info: [time] Linear solver took 0.0024216 s.
# info: Convergence criterion: |dx|=1.4017e+06, |x|=3.2886e+06, |dx|/|x|=4.2622e-01
# info: [time] Iteration #1 took 0.0044435 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0017715 s.
# info: [time] Applying Dirichlet BCs took 3.71e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 157/10000
# info: 	 residual: 7.542336e-21
#
# info: [time] Linear solver took 0.0013007 s.
# info: Convergence criterion: |dx|=1.0029e-08, |x|=3.2886e+06, |dx|/|x|=3.0497e-15
# info: [time] Iteration #2 took 0.0031254 s.
# info: [time] Solving process #0 took 0.0075861 s in time step #9
# info: [time] Time step #9 took 0.0080213 s.
# info: [time] Output of timestep 9 took 0.0066079 s.
# info: Time step #10 started. Time: 1810.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0018763 s.
# info: [time] Applying Dirichlet BCs took 4.83e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 269/10000
# info: 	 residual: 7.592682e-21
#
# info: [time] Linear solver took 0.0021565 s.
# info: Convergence criterion: |dx|=3.0224e+05, |x|=3.5648e+06, |dx|/|x|=8.4786e-02
# info: [time] Iteration #1 took 0.004117 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0016694 s.
# info: [time] Applying Dirichlet BCs took 3.92e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 157/10000
# info: 	 residual: 9.211490e-21
#
# info: [time] Linear solver took 0.0012625 s.
# info: Convergence criterion: |dx|=3.3450e-08, |x|=3.5648e+06, |dx|/|x|=9.3836e-15
# info: [time] Iteration #2 took 0.002987 s.
# info: [time] Solving process #0 took 0.0071213 s in time step #10
# info: [time] Time step #10 took 0.007558 s.
# info: [time] Output of timestep 10 took 0.006494 s.
# info: Time step #11 started. Time: 1820.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.00189 s.
# info: [time] Applying Dirichlet BCs took 4.84e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 262/10000
# info: 	 residual: 7.813118e-21
#
# info: [time] Linear solver took 0.0021039 s.
# info: Convergence criterion: |dx|=1.6946e+05, |x|=3.7257e+06, |dx|/|x|=4.5485e-02
# info: [time] Iteration #1 took 0.0040786 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0018918 s.
# info: [time] Applying Dirichlet BCs took 4.94e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 156/10000
# info: 	 residual: 7.897569e-21
#
# info: [time] Linear solver took 0.0012912 s.
# info: Convergence criterion: |dx|=8.1641e-09, |x|=3.7257e+06, |dx|/|x|=2.1913e-15
# info: [time] Iteration #2 took 0.0032736 s.
# info: [time] Solving process #0 took 0.0073713 s in time step #11
# info: [time] Time step #11 took 0.00782 s.
# info: [time] Output of timestep 11 took 0.0063733 s.
# info: Time step #12 started. Time: 1830.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0018998 s.
# info: [time] Applying Dirichlet BCs took 5.27e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 261/10000
# info: 	 residual: 6.686303e-21
#
# info: [time] Linear solver took 0.0021176 s.
# info: Convergence criterion: |dx|=1.2174e+05, |x|=3.8434e+06, |dx|/|x|=3.1674e-02
# info: [time] Iteration #1 took 0.0041053 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0016624 s.
# info: [time] Applying Dirichlet BCs took 3.79e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 157/10000
# info: 	 residual: 7.194031e-21
#
# info: [time] Linear solver took 0.0013091 s.
# info: Convergence criterion: |dx|=1.3030e-08, |x|=3.8434e+06, |dx|/|x|=3.3903e-15
# info: [time] Iteration #2 took 0.0030252 s.
# info: [time] Solving process #0 took 0.0071492 s in time step #12
# info: [time] Time step #12 took 0.0075941 s.
# info: [time] Output of timestep 12 took 0.0063225 s.
# info: Time step #13 started. Time: 1840.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0019111 s.
# info: [time] Applying Dirichlet BCs took 5.3e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 248/10000
# info: 	 residual: 9.510920e-21
#
# info: [time] Linear solver took 0.001992 s.
# info: Convergence criterion: |dx|=9.8018e+04, |x|=3.9390e+06, |dx|/|x|=2.4884e-02
# info: [time] Iteration #1 took 0.0039915 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0016695 s.
# info: [time] Applying Dirichlet BCs took 3.72e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 158/10000
# info: 	 residual: 7.382358e-21
#
# info: [time] Linear solver took 0.0012768 s.
# info: Convergence criterion: |dx|=3.3226e-08, |x|=3.9390e+06, |dx|/|x|=8.4351e-15
# info: [time] Iteration #2 took 0.0029987 s.
# info: [time] Solving process #0 took 0.0070083 s in time step #13
# info: [time] Time step #13 took 0.0074352 s.
# info: [time] Output of timestep 13 took 0.0061947 s.
# info: Time step #14 started. Time: 1850.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0019672 s.
# info: [time] Applying Dirichlet BCs took 5.08e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 256/10000
# info: 	 residual: 8.435274e-21
#
# info: [time] Linear solver took 0.0020514 s.
# info: Convergence criterion: |dx|=8.4548e+04, |x|=4.0214e+06, |dx|/|x|=2.1025e-02
# info: [time] Iteration #1 took 0.0041082 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0016168 s.
# info: [time] Applying Dirichlet BCs took 3.77e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 156/10000
# info: 	 residual: 8.623820e-21
#
# info: [time] Linear solver took 0.0012489 s.
# info: Convergence criterion: |dx|=3.7796e-08, |x|=4.0214e+06, |dx|/|x|=9.3988e-15
# info: [time] Iteration #2 took 0.0029179 s.
# info: [time] Solving process #0 took 0.007044 s in time step #14
# info: [time] Time step #14 took 0.0074903 s.
# info: [time] Output of timestep 14 took 0.006181 s.
# info: Time step #15 started. Time: 1860.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0019864 s.
# info: [time] Applying Dirichlet BCs took 5.01e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 274/10000
# info: 	 residual: 9.707172e-21
#
# info: [time] Linear solver took 0.0021967 s.
# info: Convergence criterion: |dx|=7.6375e+04, |x|=4.0955e+06, |dx|/|x|=1.8648e-02
# info: [time] Iteration #1 took 0.0042743 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.001619 s.
# info: [time] Applying Dirichlet BCs took 3.77e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 156/10000
# info: 	 residual: 9.983169e-21
#
# info: [time] Linear solver took 0.0012626 s.
# info: Convergence criterion: |dx|=5.3749e-08, |x|=4.0955e+06, |dx|/|x|=1.3124e-14
# info: [time] Iteration #2 took 0.0029344 s.
# info: [time] Solving process #0 took 0.0072272 s in time step #15
# info: [time] Time step #15 took 0.0076669 s.
# info: [time] Output of timestep 15 took 0.0062698 s.
# info: Time step #16 started. Time: 1870.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0018892 s.
# info: [time] Applying Dirichlet BCs took 4.97e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 256/10000
# info: 	 residual: 9.651536e-21
#
# info: [time] Linear solver took 0.0020774 s.
# info: Convergence criterion: |dx|=7.1220e+04, |x|=4.1642e+06, |dx|/|x|=1.7103e-02
# info: [time] Iteration #1 took 0.0040583 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0016295 s.
# info: [time] Applying Dirichlet BCs took 3.85e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 157/10000
# info: 	 residual: 8.517697e-21
#
# info: [time] Linear solver took 0.0012768 s.
# info: Convergence criterion: |dx|=2.7754e-08, |x|=4.1642e+06, |dx|/|x|=6.6649e-15
# info: [time] Iteration #2 took 0.0029592 s.
# info: [time] Solving process #0 took 0.0070376 s in time step #16
# info: [time] Time step #16 took 0.0074731 s.
# info: [time] Output of timestep 16 took 0.0066874 s.
# info: Time step #17 started. Time: 1880.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0022939 s.
# info: [time] Applying Dirichlet BCs took 5.12e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 248/10000
# info: 	 residual: 6.877844e-21
#
# info: [time] Linear solver took 0.0020041 s.
# info: Convergence criterion: |dx|=6.7885e+04, |x|=4.2293e+06, |dx|/|x|=1.6051e-02
# info: [time] Iteration #1 took 0.0043981 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0016157 s.
# info: [time] Applying Dirichlet BCs took 3.77e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 155/10000
# info: 	 residual: 9.101045e-21
#
# info: [time] Linear solver took 0.0012512 s.
# info: Convergence criterion: |dx|=1.8533e-08, |x|=4.2293e+06, |dx|/|x|=4.3820e-15
# info: [time] Iteration #2 took 0.0029191 s.
# info: [time] Solving process #0 took 0.0073367 s in time step #17
# info: [time] Time step #17 took 0.0077776 s.
# info: [time] Output of timestep 17 took 0.0061079 s.
# info: Time step #18 started. Time: 1890.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0022403 s.
# info: [time] Applying Dirichlet BCs took 6.87e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 256/10000
# info: 	 residual: 9.316122e-21
#
# info: [time] Linear solver took 0.0026107 s.
# info: Convergence criterion: |dx|=6.5687e+04, |x|=4.2919e+06, |dx|/|x|=1.5305e-02
# info: [time] Iteration #1 took 0.004988 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0018837 s.
# info: [time] Applying Dirichlet BCs took 5.66e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 157/10000
# info: 	 residual: 8.487501e-21
#
# info: [time] Linear solver took 0.0012639 s.
# info: Convergence criterion: |dx|=2.5117e-08, |x|=4.2919e+06, |dx|/|x|=5.8522e-15
# info: [time] Iteration #2 took 0.0032261 s.
# info: [time] Solving process #0 took 0.0082336 s in time step #18
# info: [time] Time step #18 took 0.0086668 s.
# info: [time] Output of timestep 18 took 0.006071 s.
# info: Time step #19 started. Time: 1900.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0021827 s.
# info: [time] Applying Dirichlet BCs took 5.3e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 262/10000
# info: 	 residual: 8.112439e-21
#
# info: [time] Linear solver took 0.0021769 s.
# info: Convergence criterion: |dx|=6.4218e+04, |x|=4.3529e+06, |dx|/|x|=1.4753e-02
# info: [time] Iteration #1 took 0.0044796 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0017064 s.
# info: [time] Applying Dirichlet BCs took 4.35e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 157/10000
# info: 	 residual: 6.510659e-21
#
# info: [time] Linear solver took 0.001273 s.
# info: Convergence criterion: |dx|=2.3199e-08, |x|=4.3529e+06, |dx|/|x|=5.3296e-15
# info: [time] Iteration #2 took 0.0030377 s.
# info: [time] Solving process #0 took 0.0075358 s in time step #19
# info: [time] Time step #19 took 0.007968 s.
# info: [time] Output of timestep 19 took 0.0061671 s.
# info: Time step #20 started. Time: 1910.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0020558 s.
# info: [time] Applying Dirichlet BCs took 5.17e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 299/10000
# info: 	 residual: 8.073023e-21
#
# info: [time] Linear solver took 0.0024175 s.
# info: Convergence criterion: |dx|=1.5068e+06, |x|=5.6865e+06, |dx|/|x|=2.6497e-01
# info: [time] Iteration #1 took 0.0045688 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0017484 s.
# info: [time] Applying Dirichlet BCs took 4.42e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 156/10000
# info: 	 residual: 9.915492e-21
#
# info: [time] Linear solver took 0.0012741 s.
# info: Convergence criterion: |dx|=1.8254e-08, |x|=5.6865e+06, |dx|/|x|=3.2100e-15
# info: [time] Iteration #2 took 0.0030919 s.
# info: [time] Solving process #0 took 0.0076809 s in time step #20
# info: [time] Time step #20 took 0.0081187 s.
# info: [time] Output of timestep 20 took 0.0064317 s.
# info: Time step #21 started. Time: 1920.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0019642 s.
# info: [time] Applying Dirichlet BCs took 5.1e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 283/10000
# info: 	 residual: 6.408948e-21
#
# info: [time] Linear solver took 0.0023242 s.
# info: Convergence criterion: |dx|=3.6648e+05, |x|=6.0425e+06, |dx|/|x|=6.0650e-02
# info: [time] Iteration #1 took 0.0043792 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0016616 s.
# info: [time] Applying Dirichlet BCs took 4.09e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 158/10000
# info: 	 residual: 8.849625e-21
#
# info: [time] Linear solver took 0.0012675 s.
# info: Convergence criterion: |dx|=3.4263e-08, |x|=6.0425e+06, |dx|/|x|=5.6703e-15
# info: [time] Iteration #2 took 0.0029883 s.
# info: [time] Solving process #0 took 0.0073866 s in time step #21
# info: [time] Time step #21 took 0.0078216 s.
# info: [time] Output of timestep 21 took 0.0065547 s.
# info: Time step #22 started. Time: 1930.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0019816 s.
# info: [time] Applying Dirichlet BCs took 5.03e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 276/10000
# info: 	 residual: 9.584411e-21
#
# info: [time] Linear solver took 0.0022251 s.
# info: Convergence criterion: |dx|=2.3204e+05, |x|=6.2678e+06, |dx|/|x|=3.7020e-02
# info: [time] Iteration #1 took 0.0042967 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.001605 s.
# info: [time] Applying Dirichlet BCs took 3.71e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 156/10000
# info: 	 residual: 8.204965e-21
#
# info: [time] Linear solver took 0.0012646 s.
# info: Convergence criterion: |dx|=3.3231e-08, |x|=6.2678e+06, |dx|/|x|=5.3018e-15
# info: [time] Iteration #2 took 0.0029211 s.
# info: [time] Solving process #0 took 0.0072365 s in time step #22
# info: [time] Time step #22 took 0.0076707 s.
# info: [time] Output of timestep 22 took 0.0063626 s.
# info: Time step #23 started. Time: 1940.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0019737 s.
# info: [time] Applying Dirichlet BCs took 5.3e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 248/10000
# info: 	 residual: 8.675569e-21
#
# info: [time] Linear solver took 0.002003 s.
# info: Convergence criterion: |dx|=1.8470e+05, |x|=6.4453e+06, |dx|/|x|=2.8656e-02
# info: [time] Iteration #1 took 0.0040718 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0016094 s.
# info: [time] Applying Dirichlet BCs took 3.79e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 158/10000
# info: 	 residual: 7.906859e-21
#
# info: [time] Linear solver took 0.0012659 s.
# info: Convergence criterion: |dx|=2.2837e-08, |x|=6.4453e+06, |dx|/|x|=3.5432e-15
# info: [time] Iteration #2 took 0.0029278 s.
# info: [time] Solving process #0 took 0.0070186 s in time step #23
# info: [time] Time step #23 took 0.0074567 s.
# info: [time] Output of timestep 23 took 0.0064261 s.
# info: Time step #24 started. Time: 1950.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0019792 s.
# info: [time] Applying Dirichlet BCs took 5.11e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 276/10000
# info: 	 residual: 9.079466e-21
#
# info: [time] Linear solver took 0.0022163 s.
# info: Convergence criterion: |dx|=1.6145e+05, |x|=6.5985e+06, |dx|/|x|=2.4468e-02
# info: [time] Iteration #1 took 0.0042896 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.001616 s.
# info: [time] Applying Dirichlet BCs took 3.76e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 156/10000
# info: 	 residual: 8.924745e-21
#
# info: [time] Linear solver took 0.0012622 s.
# info: Convergence criterion: |dx|=4.9329e-08, |x|=6.5985e+06, |dx|/|x|=7.4758e-15
# info: [time] Iteration #2 took 0.0029309 s.
# info: [time] Solving process #0 took 0.0072395 s in time step #24
# info: [time] Time step #24 took 0.0076739 s.
# info: [time] Output of timestep 24 took 0.006608 s.
# info: Time step #25 started. Time: 1960.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.002044 s.
# info: [time] Applying Dirichlet BCs took 5.11e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 260/10000
# info: 	 residual: 9.100713e-21
#
# info: [time] Linear solver took 0.0021369 s.
# info: Convergence criterion: |dx|=1.4828e+05, |x|=6.7375e+06, |dx|/|x|=2.2008e-02
# info: [time] Iteration #1 took 0.0042758 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0016314 s.
# info: [time] Applying Dirichlet BCs took 3.76e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 155/10000
# info: 	 residual: 9.397462e-21
#
# info: [time] Linear solver took 0.0012614 s.
# info: Convergence criterion: |dx|=3.8856e-08, |x|=6.7375e+06, |dx|/|x|=5.7671e-15
# info: [time] Iteration #2 took 0.0029452 s.
# info: [time] Solving process #0 took 0.0072398 s in time step #25
# info: [time] Time step #25 took 0.0076795 s.
# info: [time] Output of timestep 25 took 0.0062392 s.
# info: Time step #26 started. Time: 1970.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0019616 s.
# info: [time] Applying Dirichlet BCs took 5e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 270/10000
# info: 	 residual: 7.487742e-21
#
# info: [time] Linear solver took 0.0022803 s.
# info: Convergence criterion: |dx|=1.4024e+05, |x|=6.8677e+06, |dx|/|x|=2.0420e-02
# info: [time] Iteration #1 took 0.0043323 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0016445 s.
# info: [time] Applying Dirichlet BCs took 3.84e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 156/10000
# info: 	 residual: 8.985956e-21
#
# info: [time] Linear solver took 0.0012594 s.
# info: Convergence criterion: |dx|=2.8708e-08, |x|=6.8677e+06, |dx|/|x|=4.1801e-15
# info: [time] Iteration #2 took 0.0029576 s.
# info: [time] Solving process #0 took 0.0073077 s in time step #26
# info: [time] Time step #26 took 0.0077449 s.
# info: [time] Output of timestep 26 took 0.0062621 s.
# info: Time step #27 started. Time: 1980.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0019674 s.
# info: [time] Applying Dirichlet BCs took 5.08e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 257/10000
# info: 	 residual: 7.861069e-21
#
# info: [time] Linear solver took 0.0020635 s.
# info: Convergence criterion: |dx|=1.3511e+05, |x|=6.9922e+06, |dx|/|x|=1.9322e-02
# info: [time] Iteration #1 took 0.0041206 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0016001 s.
# info: [time] Applying Dirichlet BCs took 3.79e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 156/10000
# info: 	 residual: 9.276293e-21
#
# info: [time] Linear solver took 0.001253 s.
# info: Convergence criterion: |dx|=2.2506e-08, |x|=6.9922e+06, |dx|/|x|=3.2187e-15
# info: [time] Iteration #2 took 0.0029065 s.
# info: [time] Solving process #0 took 0.0070447 s in time step #27
# info: [time] Time step #27 took 0.0074921 s.
# info: [time] Output of timestep 27 took 0.0062743 s.
# info: Time step #28 started. Time: 1990.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0019748 s.
# info: [time] Applying Dirichlet BCs took 4.92e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 270/10000
# info: 	 residual: 9.405395e-21
#
# info: [time] Linear solver took 0.0023982 s.
# info: Convergence criterion: |dx|=1.3175e+05, |x|=7.1131e+06, |dx|/|x|=1.8522e-02
# info: [time] Iteration #1 took 0.0044783 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0023208 s.
# info: [time] Applying Dirichlet BCs took 0.0001187 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 156/10000
# info: 	 residual: 8.730114e-21
#
# info: [time] Linear solver took 0.0017941 s.
# info: Convergence criterion: |dx|=2.0074e-08, |x|=7.1131e+06, |dx|/|x|=2.8221e-15
# info: [time] Iteration #2 took 0.0043192 s.
# info: [time] Solving process #0 took 0.0088235 s in time step #28
# info: [time] Time step #28 took 0.0093333 s.
# info: [time] Output of timestep 28 took 0.007085 s.
# info: Time step #29 started. Time: 2000.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0019656 s.
# info: [time] Applying Dirichlet BCs took 5.17e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# ...
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 157/10000
# info: 	 residual: 7.189609e-21
#
# info: [time] Linear solver took 0.001339 s.
# info: Convergence criterion: |dx|=3.2991e-07, |x|=2.9147e+07, |dx|/|x|=1.1319e-14
# info: [time] Iteration #2 took 0.0030281 s.
# info: [time] Solving process #0 took 0.0071365 s in time step #87
# info: [time] Time step #87 took 0.0075758 s.
# info: [time] Output of timestep 87 took 0.006331 s.
# info: Time step #88 started. Time: 2590.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0021241 s.
# info: [time] Applying Dirichlet BCs took 4.75e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 241/10000
# info: 	 residual: 8.597032e-21
#
# info: [time] Linear solver took 0.0019344 s.
# info: Convergence criterion: |dx|=1.9971e+05, |x|=2.9013e+07, |dx|/|x|=6.8835e-03
# info: [time] Iteration #1 took 0.0041466 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0016401 s.
# info: [time] Applying Dirichlet BCs took 4.18e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 156/10000
# info: 	 residual: 8.349967e-21
#
# info: [time] Linear solver took 0.0012571 s.
# info: Convergence criterion: |dx|=9.7785e-08, |x|=2.9013e+07, |dx|/|x|=3.3704e-15
# info: [time] Iteration #2 took 0.0029537 s.
# info: [time] Solving process #0 took 0.0071182 s in time step #88
# info: [time] Time step #88 took 0.0075582 s.
# info: [time] Output of timestep 88 took 0.0066098 s.
# info: Time step #89 started. Time: 2600.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0019931 s.
# info: [time] Applying Dirichlet BCs took 4.76e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 233/10000
# info: 	 residual: 9.591007e-21
#
# info: [time] Linear solver took 0.0019619 s.
# info: Convergence criterion: |dx|=1.3671e+05, |x|=2.8923e+07, |dx|/|x|=4.7266e-03
# info: [time] Iteration #1 took 0.0040443 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0017112 s.
# info: [time] Applying Dirichlet BCs took 4.43e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 155/10000
# info: 	 residual: 7.973694e-21
#
# info: [time] Linear solver took 0.0012371 s.
# info: Convergence criterion: |dx|=2.7004e-07, |x|=2.8923e+07, |dx|/|x|=9.3368e-15
# info: [time] Iteration #2 took 0.0030103 s.
# info: [time] Solving process #0 took 0.0070728 s in time step #89
# info: [time] Time step #89 took 0.0075107 s.
# info: [time] Output of timestep 89 took 0.0064807 s.
# info: Time step #90 started. Time: 2610.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0019645 s.
# info: [time] Applying Dirichlet BCs took 4.86e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 224/10000
# info: 	 residual: 6.411514e-21
#
# info: [time] Linear solver took 0.0018086 s.
# info: Convergence criterion: |dx|=9.3774e+04, |x|=2.8861e+07, |dx|/|x|=3.2492e-03
# info: [time] Iteration #1 took 0.0038588 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.001648 s.
# info: [time] Applying Dirichlet BCs took 5.7e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 155/10000
# info: 	 residual: 8.726622e-21
#
# info: [time] Linear solver took 0.0012853 s.
# info: Convergence criterion: |dx|=1.0690e-07, |x|=2.8861e+07, |dx|/|x|=3.7039e-15
# info: [time] Iteration #2 took 0.0030223 s.
# info: [time] Solving process #0 took 0.006901 s in time step #90
# info: [time] Time step #90 took 0.0073537 s.
# info: [time] Output of timestep 90 took 0.0064658 s.
# info: Time step #91 started. Time: 2620.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0019851 s.
# info: [time] Applying Dirichlet BCs took 4.88e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 224/10000
# info: 	 residual: 8.459822e-21
#
# info: [time] Linear solver took 0.0018105 s.
# info: Convergence criterion: |dx|=6.4339e+04, |x|=2.8819e+07, |dx|/|x|=2.2325e-03
# info: [time] Iteration #1 took 0.0039001 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0017084 s.
# info: [time] Applying Dirichlet BCs took 4.3e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 156/10000
# info: 	 residual: 7.991481e-21
#
# info: [time] Linear solver took 0.0012542 s.
# info: Convergence criterion: |dx|=2.6771e-07, |x|=2.8819e+07, |dx|/|x|=9.2892e-15
# info: [time] Iteration #2 took 0.0030209 s.
# info: [time] Solving process #0 took 0.0069391 s in time step #91
# info: [time] Time step #91 took 0.0073987 s.
# info: [time] Output of timestep 91 took 0.0063007 s.
# info: Time step #92 started. Time: 2630.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0019902 s.
# info: [time] Applying Dirichlet BCs took 4.89e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 222/10000
# info: 	 residual: 9.962513e-21
#
# info: [time] Linear solver took 0.0017972 s.
# info: Convergence criterion: |dx|=4.4089e+04, |x|=2.8791e+07, |dx|/|x|=1.5314e-03
# info: [time] Iteration #1 took 0.003887 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0016109 s.
# info: [time] Applying Dirichlet BCs took 4.14e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 156/10000
# info: 	 residual: 8.134061e-21
#
# info: [time] Linear solver took 0.0012555 s.
# info: Convergence criterion: |dx|=8.2991e-08, |x|=2.8791e+07, |dx|/|x|=2.8826e-15
# info: [time] Iteration #2 took 0.0029216 s.
# info: [time] Solving process #0 took 0.0068285 s in time step #92
# info: [time] Time step #92 took 0.0072672 s.
# info: [time] Output of timestep 92 took 0.0069165 s.
# info: Time step #93 started. Time: 2640.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0020021 s.
# info: [time] Applying Dirichlet BCs took 6.61e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 206/10000
# info: 	 residual: 8.061911e-21
#
# info: [time] Linear solver took 0.0016569 s.
# info: Convergence criterion: |dx|=3.0132e+04, |x|=2.8772e+07, |dx|/|x|=1.0473e-03
# info: [time] Iteration #1 took 0.0037702 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0016214 s.
# info: [time] Applying Dirichlet BCs took 4.24e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 157/10000
# info: 	 residual: 8.047708e-21
#
# info: [time] Linear solver took 0.0012524 s.
# info: Convergence criterion: |dx|=2.1098e-07, |x|=2.8772e+07, |dx|/|x|=7.3327e-15
# info: [time] Iteration #2 took 0.0029306 s.
# info: [time] Solving process #0 took 0.0067199 s in time step #93
# info: [time] Time step #93 took 0.0071552 s.
# info: [time] Output of timestep 93 took 0.0065804 s.
# info: Time step #94 started. Time: 2650.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0019702 s.
# info: [time] Applying Dirichlet BCs took 4.76e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 214/10000
# info: 	 residual: 9.653311e-21
#
# info: [time] Linear solver took 0.0017336 s.
# info: Convergence criterion: |dx|=2.0504e+04, |x|=2.8759e+07, |dx|/|x|=7.1295e-04
# info: [time] Iteration #1 took 0.0037932 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0016056 s.
# info: [time] Applying Dirichlet BCs took 4.17e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 155/10000
# info: 	 residual: 9.643579e-21
#
# info: [time] Linear solver took 0.0012467 s.
# info: Convergence criterion: |dx|=6.7394e-08, |x|=2.8759e+07, |dx|/|x|=2.3434e-15
# info: [time] Iteration #2 took 0.0029086 s.
# info: [time] Solving process #0 took 0.0067199 s in time step #94
# info: [time] Time step #94 took 0.0071606 s.
# info: [time] Output of timestep 94 took 0.006779 s.
# info: Time step #95 started. Time: 2660.79025. Step size: 10.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0019818 s.
# info: [time] Applying Dirichlet BCs took 4.85e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 195/10000
# info: 	 residual: 9.396832e-21
#
# info: [time] Linear solver took 0.001583 s.
# info: Convergence criterion: |dx|=1.3864e+04, |x|=2.8751e+07, |dx|/|x|=4.8220e-04
# info: [time] Iteration #1 took 0.0036548 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0016 s.
# info: [time] Applying Dirichlet BCs took 4.1e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 155/10000
# info: 	 residual: 9.477411e-21
#
# info: [time] Linear solver took 0.0012522 s.
# info: Convergence criterion: |dx|=1.0640e-07, |x|=2.8751e+07, |dx|/|x|=3.7007e-15
# info: [time] Iteration #2 took 0.0029079 s.
# info: [time] Solving process #0 took 0.0065815 s in time step #95
# info: [time] Time step #95 took 0.0070179 s.
# info: [time] Output of timestep 95 took 0.006598 s.
# info: Time step #96 started. Time: 2669.8090000000002. Step size: 9.0187500000001819.
# info: Solving process #0 started.
# info: Iteration #1 started.
# info: [time] Assembly took 0.0020014 s.
# info: [time] Applying Dirichlet BCs took 4.93e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 194/10000
# info: 	 residual: 9.067390e-21
#
# info: [time] Linear solver took 0.0015759 s.
# info: Convergence criterion: |dx|=8.6664e+03, |x|=2.8746e+07, |dx|/|x|=3.0148e-04
# info: [time] Iteration #1 took 0.0036679 s.
# info: Iteration #2 started.
# info: [time] Assembly took 0.0016224 s.
# info: [time] Applying Dirichlet BCs took 4.21e-05 s.
# info: ------------------------------------------------------------------
# info: *** Eigen solver compute()
# info: -> compute with Eigen iterative linear solver CG (precon DIAGONAL)
# info: ------------------------------------------------------------------
# info: *** Eigen solver solve()
# info: -> solve with Eigen iterative linear solver CG (precon DIAGONAL)
# info: 	 iteration: 154/10000
# info: 	 residual: 9.347769e-21
#
# info: [time] Linear solver took 0.001235 s.
# info: Convergence criterion: |dx|=2.7993e-07, |x|=2.8746e+07, |dx|/|x|=9.7381e-15
# info: [time] Iteration #2 took 0.0029134 s.
# info: [time] Solving process #0 took 0.0065996 s in time step #96
# info: [time] Time step #96 took 0.0070376 s.
# info: [time] Output of timestep 96 took 0.0064493 s.
# info: The whole computation of the time stepping took 96 steps, in which
# 	 the accepted steps are 96, and the rejected steps are 0.
#
# info: [time] Execution took 1.39039 s.
# info: OGS terminated on 2026-03-27 12:07:43+0100.

# %% [markdown]
# ## Results and visualization

# %% [markdown]
# ### Post-processing

# %%
pvd_path1 = Path("_out_2/BH10_20180718_40.6.pvd")
ms1 = ot.MeshSeries(pvd_path1)
pressure=ot.variables.pressure
pressure= pressure.replace(output_unit="MPa")

# %%
y=-40.6
r_st1=ddict['r_w']
r_en1=re3

coords=np.array(np.geomspace([r_st1,y,1e-18],[r_en1,y,1e-18],5).round(3)) 
ms_probes1 = ms1.extract_probe(ms1,points=coords)

labels1 = [f"r={pt[0]:>5.3f}, y={y}" for pt in coords]
print(f'midpoint along well: {y}m {'\n'}wellbore radius: {r_st1} m, {'/n'}Boundary (aprox) distance: {r_en1} m')
print(f'r to evaluate: {coords[:,0]} m')

timeogs1=ms_probes1.timevalues
pwsr3p= step_rate_r(pd_lsrf_fb, timeogs1 , tp, q_array, ddict, k_val3, r_val3,re3)
diff1 = pwsr3p - ms_probes1['pressure']
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 97/97 [00:01<00:00, 56.82it/s]
# midpoint along well: -40.6m
# wellbore radius: 0.038 m, /nBoundary (aprox) distance: 14 m
# r to evaluate: [ 0.038  0.166  0.729  3.196 14.   ] m

# %% [markdown]
# ### Analytical and Numerical OGS comparison

# %%
fig15, axs= plt.subplots(nrows=1, ncols=2,figsize=[15,6], sharex=True)
ot.plot.line(ms_probes1,"time", pressure,ax=axs[0], color='k',fontsize=18,label=labels1)
axs[0].plot(timeogs1, pwsr3p/1e6,color='tab:red', label=line_labels13) 
axs[1].plot(timeogs1, diff1/1e6, label=line_labels13)

fig15.suptitle("Line-source analytical rf-nfb,   - Numerical OGS Neumann Line-source") 
axs[0].set_title("Resuls by distance (radii)")
axs[1].set_title("Difference analytical-OGS")

axs[1].set_xlabel("time / s")
axs[1].set_ylabel("diff / MPa")

axs[0].legend()
axs[1].legend()
axs[1].grid()
plt.tight_layout()

plt.show()
#fig13.savefig(f"lsrfn_fb_2D_{TESTSR}.pdf",format='pdf') #report figure

# %%
#Pwd finite source vs OGS STIMTEC
pw2= step_rate_r(pwd_fsrf_fb, timeogs1, tp, q_array, ddict, k_val2, r_val2,re2,am2)
ms_probes1_w=ms_probes1['pressure'][0:,0]
diff2 = pw2-ms_probes1_w

fig16, axs= plt.subplots(nrows=1, ncols=2,figsize=[15,6], sharex=True)
axs[0].plot(timeogs1,ms_probes1_w/1e6, color='k',label=labels1[0])
axs[0].plot(timeogs1, pw2/1e6,color='tab:red', label=line_labels13[0]) 
axs[1].plot(timeogs1, diff2/1e6, label=line_labels13[0])

fig16.suptitle("Finite-source analytical rf-nfb wellbore  - Numerical OGS Neumann Line-source") 
axs[0].set_title("Results at wellbore")
axs[1].set_title("Difference analytical-OGS")

axs[0].set_xlabel("time / s")
axs[0].set_ylabel("Pressure / MPa")
axs[1].set_xlabel("time / s")
axs[1].set_ylabel("diff / MPa")

axs[0].legend()
axs[0].grid()
axs[1].legend()
axs[1].grid()
plt.tight_layout()
plt.show()
#fig13.savefig(f"fsrfn_fb_2D_{TESTSR}.pdf",format='pdf') #report figure
